# %%
import torch
import torch.nn as nn
import numpy as np
import math


'''
1. Normalization 과 Activation 을 포함한 Conv. Layer 모듈 생성 
'''
class ConvBlock(nn.Module):
    def __init__(self, input_size, output_size, kernel_size=3, stride=1, padding=1, bias=True, activation='prelu', norm=None):
        super(ConvBlock, self).__init__()
        self.conv = torch.nn.Conv2d(input_size, output_size, kernel_size, stride, padding, bias=bias)

        self.norm = norm
        if self.norm =='batch':
            self.bn = torch.nn.BatchNorm2d(output_size)
        elif self.norm == 'instance':
            self.bn = torch.nn.InstanceNorm2d(output_size)
        
        # self.bn : Conv Layer 출력에서 normalization 을 Instance 로 할지 Batch 로 할지 선택
        
        self.activation = activation
        if self.activation == 'relu':
            self.act = torch.nn.ReLU(True)
        elif self.activation == 'prelu':
            self.act = torch.nn.PReLU()
        elif self.activation == 'lrelu':
            self.act = torch.nn.LeakyReLU(0.2, True)
        elif self.activation == 'tanh':
            self.act = torch.nn.Tanh()
        elif self.activation == 'sigmoid':
            self.act = torch.nn.Sigmoid()
        
        # self.act : Conv Layer 출력 Activation Function 선택

        for m in self.modules():
            classname = m.__class__.__name__
            if classname.find('Conv2d') != -1:
                torch.nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()
            # Conv2d Layer 라면 He 방법으로 해당 Layer 의 weight 들을 초기화, bias 가 True 면 bias 를 0 으로 초기화
            elif classname.find('ConvTranspose2d') != -1:
                torch.nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()
           # ConvTranspose2d Layer 라면 He 방법으로 해당 Layer 의 weight 들을 초기화, bias 가 True 면 bias 를 0 으로 초기화
        
    def forward(self, x):
        if self.norm is not None:
            out = self.bn(self.conv(x))
        else:
            out = self.conv(x)

        if self.activation is not None:
            return self.act(out)
        else:
            return out
    
'''
2. (1)에서 만든 ConvBlock() 을 사용하여 SRCNN 을 만듬
    이때, 각 layer1, 2, 3 에서 weights 를 초기화
'''

class SRCNN(nn.Module):
    def __init__(self):
        super(SRCNN, self).__init__()
        
        self.layer1 = ConvBlock(3, 64, kernel_size=9, stride=1, padding=4, activation='relu', norm=None)
        self.layer2 = ConvBlock(64, 32, kernel_size=3, stride=1, padding=1, activation='relu', norm=None)
        self.layer3 = ConvBlock(32, 3, kernel_size=5, stride=1, padding=2, activation=None, norm=None)
        
    def forward(self, x):
        f1 = self.layer1(x)
        f2 = self.layer2(f1)
        y = self.layer3(f2)
        
        return y

print('finish')
# Out:
# finish

# %%
# 모델 확인

import os
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
from google.colab import drive
from torchsummary import summary

drive.mount('/content/gdrive')

'''
1. GPU 설정 및 parameter print
'''
gpus_list = range(1)
cudnn.benchmark = True

cuda = True
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

model = SRCNN()

'''
4. GPU 사용 여부 및 pretrained model 사용 여부 설정
'''
if cuda:
  model = model.cuda(gpus_list[0])
  model = torch.nn.DataParallel(model, device_ids=gpus_list)
    
summary(model, (3,32,32))
# Out:
# Mounted at /content/gdrive
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]          15,616
#               ReLU-2           [-1, 64, 32, 32]               0
#          ConvBlock-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]          18,464
#               ReLU-5           [-1, 32, 32, 32]               0
#          ConvBlock-6           [-1, 32, 32, 32]               0
#             Conv2d-7            [-1, 3, 32, 32]           2,403
#          ConvBlock-8            [-1, 3, 32, 32]               0
#              SRCNN-9            [-1, 3, 32, 32]               0
# ================================================================
# Total params: 36,483
# Trainable params: 36,483
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.32
# Params size (MB): 0.14
# Estimated Total Size (MB): 2.47
# ----------------------------------------------------------------

# %%
# 데이터 전처리 & 사용자 정의 data

from __future__ import print_function
import argparse

import os
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import *
import torch
import math
from os.path import join
import torch.utils.data as data
import numpy as np
from os import listdir
from os.path import join
from PIL import Image, ImageOps, ImageFilter
import random
from random import randrange
from math import sqrt

'''
1. filename 에 .png, .jpg, .jpeg 중 하나라도 있으면 True 를 반환하는 함수
'''
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg"])

'''
2. PIL 을 이용하여 filepath에서 이미지를 불러오고 RGB 로 convert 하여 반환하는 함수
'''
def load_img(filepath):
    img = Image.open(filepath).convert('RGB')
    return img

'''
3. PIL 을 이용하여 이미지를 Bicubic 으로 scale 만큼 High Resolution 으로 만드는 함수
'''
def rescale_img(img_in, scale):
    size_in = img_in.size
    # size_in = img_in 의 (width, height) tuple
    new_size_in = tuple([int(x * scale) for x in size_in])
    # new_size_in = (width * scale, height * scale)
    img_in = img_in.resize(new_size_in, resample=Image.BICUBIC)
    return img_in

'''
4. img_tar = load_img 함수를 이용하여 index 번째 image 를 RGB 로 불러온 이미지 
   img_in = target 으로 불러온 이미지를 Bicubic 으로 downscale 한 이미지 -> (사용할 일 없음)
   img_bic = rescale_img 함수로 input 을 다시 같은 비율로 upscale 한 이미지

   training 에는 img_tar, img_bic 을 사용할 것이고, 이들 이미지 임의의 영역을
   upscale_factor*n x upscale_factor*n 크기로 잘라 이미지 크기를 같게 만들어 줌
   
   잘린 이미지는 같은 random point 에서 시작하여 잘리므로 이미지가 나타내는 임의의 영역이 같음
'''
def get_patch(img_in, img_tar, img_bic, patch_size, scale, ix=-1, iy=-1):
    (ih, iw) = img_in.size
    (th, tw) = (scale * ih, scale * iw)

    patch_mult = scale #if len(scale) > 1 else 1
    tp = patch_mult * patch_size
    # tp = upscale_factor*n (n = patch_size)
    ip = tp // scale
    # ip = n (n = patch_size)
    
    if ix == -1:
        ix = random.randrange(0, iw - ip + 1)
    if iy == -1:
        iy = random.randrange(0, ih - ip + 1)

    (tx, ty) = (scale * ix, scale * iy)

    img_in = img_in.crop((iy,ix,iy + ip, ix + ip))
    # 원본이미지 임의의 영역을 n x n 크기로 자름
    img_tar = img_tar.crop((ty,tx,ty + tp, tx + tp))
    # downscale 한 이미지 임의의 영역을 upscale_factor*n x upscale_factor*n 크기로 자름
    img_bic = img_bic.crop((ty,tx,ty + tp, tx + tp))
    # upscale 한 이미지 임의의 영역을 upscale_factor*n x upscale_factor*n 크기로 자름            
    info_patch = {
        'ix': ix, 'iy': iy, 'ip': ip, 'tx': tx, 'ty': ty, 'tp': tp}
    # info_patch 에는 어떤 크기로 crop 했는지에 대한 정보가 있음
    return img_in, img_tar, img_bic, info_patch

'''
5. 이미지데이터 증강(augmentation)
'''
def augment(img_in, img_tar, img_bic, flip_h=True, rot=True):
    info_aug = {'flip_h': False, 'flip_v': False, 'trans': False}
    
    if random.random() < 0.5 and flip_h:
        img_in = ImageOps.flip(img_in)
        img_tar = ImageOps.flip(img_tar)
        img_bic = ImageOps.flip(img_bic)
        info_aug['flip_h'] = True
    # 50%의 확률로, flip_h = True 면 img_in, img_tar, img_bic 을 모두 flip

    if rot:
        if random.random() < 0.5:
            img_in = ImageOps.mirror(img_in)
            img_tar = ImageOps.mirror(img_tar)
            img_bic = ImageOps.mirror(img_bic)
            info_aug['flip_v'] = True
        if random.random() < 0.5:
            img_in = img_in.rotate(180)
            img_tar = img_tar.rotate(180)
            img_bic = img_bic.rotate(180)
            info_aug['trans'] = True
    # 50%의 확률로, rot = True 면 img_in, img_tar, img_bic 을 모두 mirror & 180도 rotate
    
    return img_in, img_tar, img_bic, info_aug
    # info_aug = 출력된 이미지에 어떤 preprocessing 을 했는지 알려줌
    
'''
6. PIL 이미지나 ndarray 이미지를 Tensor로 바꾸어주는 함수
   -> ToTensor 함수 사용시 이미지 pixel 값은 0~255 에서 0~1 로 바뀜
'''
def transform():
    return Compose([ToTensor(),])

'''
7.사용자 정의 data 로드 - Training Data 
'''        
class DatasetFromFolder(data.Dataset):
    '''
    def __init__(self, index) 에서는 필요한 변수를 선언 하고 'data 경로' 를 load 한다
    '''
    def __init__(self, image_dir, patch_size, upscale_factor, data_augmentation, transform=None):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]
        # self.image_filenames = image_dir 에 있는 모든 이미지의 경로 list
        self.patch_size = patch_size
        self.upscale_factor = upscale_factor
        self.transform = transform
        self.data_augmentation = data_augmentation
    '''
    def __getitem__(self, index) 에서는 index 번째 data를 return 하도록 코드를 짠다
    '''
    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        # target = load_img 함수를 이용하여 index 번째 image 를 RGB 로 불러온 이미지
        input = target.resize((int(target.size[0]/self.upscale_factor),int(target.size[1]/self.upscale_factor)), Image.BICUBIC) 
        # input = target 으로 불러온 이미지를 Bicubic 으로 downscale 한 이미지
        bicubic = rescale_img(input, self.upscale_factor)
        # bicubic = rescale_img 함수로 input 을 다시 같은 비율로 upscale 한 이미지
        
        input, target, bicubic, _ = get_patch(input,target,bicubic,self.patch_size, self.upscale_factor)
        # input, target, bicubic 이미지를 (upscale_factor*patch_size x upscale_factor*patch_size) 로 crop
        
        if self.data_augmentation:
            input, target, bicubic, _ = augment(input, target, bicubic)
        # data_augmentation = True 라면, 세 이미지를 augment 함수로 증강, img_aug 는 필요 없음
        
        if self.transform:
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
        # self.transform = True 라면, 세 이미지를 PIL image 에서 Tensor로 바꾸어 줌
        return input, target, bicubic
    '''
    def __len__(self) 에서는 data의 len을 return 하도록 코드를 짠다
    '''
    def __len__(self):
        return len(self.image_filenames)
    
'''
8.사용자 정의 data 로드 - Test Data 
   -> file 이름까지 사용자 정의 데이터화 시킴
   -> get_patch 함수를 사용하지 않기 때문에, SRCNN 의 입력으로 (원본 이미지 xscale) 된 이미지가 들어감
'''
class DatasetFromFolderEval(data.Dataset):
    def __init__(self, lr_dir, upscale_factor, transform=None):
        super(DatasetFromFolderEval, self).__init__()
        self.image_filenames = [join(lr_dir, x) for x in listdir(lr_dir) if is_image_file(x)]
        self.upscale_factor = upscale_factor
        self.transform = transform

    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        # target = load_img 함수를 이용하여 index 번째 image 를 RGB 로 불러온 이미지
        _, file = os.path.split(self.image_filenames[index])
        # file = 이미지 경로 list 에서 file 이름만 잘라 냄

        input = target.resize((int(target.size[0]/self.upscale_factor),int(target.size[1]/self.upscale_factor)), Image.BICUBIC) 
        # input = target 으로 불러온 이미지를 Bicubic 으로 downscale 한 이미지
        bicubic = rescale_img(input, self.upscale_factor)
        # bicubic = rescale_img 함수로 input 을 다시 같은 비율로 upscale 한 이미지
        
        if self.transform:
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
         # self.transform = True 라면, 세 이미지를 PIL image 에서 Tensor로 바꾸어 줌
        
        return input, bicubic, target, file
        # file 이름까지 return
      
    def __len__(self):
        return len(self.image_filenames)
'''
9. Training Data 불러오기
'''
def get_training_set(data_dir, hr, upscale_factor, patch_size, data_augmentation):
    hr_dir = join(data_dir, hr)
    return DatasetFromFolder(hr_dir,patch_size, upscale_factor, data_augmentation,
                             transform=transform())
'''
10. Test Data 불러오기
'''
def get_eval_set(lr_dir, upscale_factor):
    return DatasetFromFolderEval(lr_dir, upscale_factor,
                             transform=transform())

print('finish')
# Out:
# finish

# %%
# Data Load & Model Load & Optimizer 
# Training

from __future__ import print_function
import argparse
from math import log10

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import pdb
import socket
import time
import easydict

from torch.utils.tensorboard import SummaryWriter

from google.colab import drive
drive.mount('/content/gdrive')

opt = easydict.EasyDict({ 
    "batchSize": 32,           # batch size - 한번에 training할 patch의 숫자
    "lr": 0.01,                # learning rate
    "upscale_factor": 2,       # Upscale 정도
    "patch_size": 32,         # 입력 이미지 크기

    "start_epoch": 1,           
    "nEpochs": 100,       # epoch 횟수
    "snapshots": 10,           # weight 저장 주기
   
    "data_dir":"/content/gdrive/My Drive/졸업논문/data_800개/train", # dataset이 저장된 위치
    "hr_train_dataset": "DIV2K_train_HR", # training에 사용할 dataset 종류

    "model_type": "WCNN",         # 모델이름
    "save_folder": "/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/", # weight 저장 위치

    "pretrained_sr": None, # pretrained model 경로
    "pretrained": False,
    "data_augmentation": False,
    "gpu_mode": True,
    "threads": 1, 
    "gpus": 1 # 사용할 gpu 번호
    })

'''
1. Training Data 로드
'''
print('===> Loading datasets')
train_set = get_training_set(opt.data_dir, opt.hr_train_dataset, opt.upscale_factor, opt.patch_size, opt.data_augmentation)
training_data_loader = DataLoader(dataset=train_set, num_workers=opt.threads, batch_size=opt.batchSize, shuffle=True)

'''
2. WCNN 빌드 및 가중치 초기화 (가중치 초기화는 빌드와 동시에 수행)
'''
print('===> Building model ', opt.model_type)
model = SRCNN()
print('===> Weight Initialization ')

'''
3. Optimizer & Criterion 정의 
  -> MSE loss 사용
  -> Optimizer는 Adam 사용
'''
criterion = nn.MSELoss() 
optimizer = optimizer = optim.Adam(model.parameters(), lr=opt.lr, betas=(0.9, 0.999), eps=1e-8)
# betas = SGD + Momentum 에서 momentum값, 0.9에서 시작하여 0.999로 증가

'''
4. GPU 설정 및 parameter print
'''
gpus_list = range(opt.gpus)
cudnn.benchmark = True
print(opt)

cuda = opt.gpu_mode
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

'''
5. GPU 사용 여부 및 pretrained model 설정
'''
if cuda:
    model = model.cuda(gpus_list[0])
    model = torch.nn.DataParallel(model, device_ids=gpus_list)
    criterion = criterion.cuda(gpus_list[0])
    
if opt.pretrained:
    model_name = os.path.join(opt.pretrained_sr)
    checkpoint = torch.load(model_name)

    model.load_state_dict(checkpoint['model_state_dict'])
    loss = checkpoint['loss']
    opt.start_epoch = checkpoint['epoch']
    print('Pre-trained SR model is loaded.')
    # pretrained model 불러오기

'''
6. 한번의 epoch 에서 수행하는 과정 정의 및 Tensorboard
'''
# %load_ext tensorboard

# %tensorboard tensorboard --logdir=/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/logs_scale=2/ --port=7007

writer = SummaryWriter('/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/logs_scale=2/')
# log 를 저장할 위치 지정

loss_list = []

def train(epoch):
    epoch_loss = 0
    model.train()
    # model.train() 을 호출하여 학습 모드로 전환
    '''
    이때, 각 이미지는 'mini batch' 갯수만큼 가져온다!
    이때, autograd.Variable 을 사용하는 이유는 batch_data 라는 list 에 있는 input, target, blur_img 를 Tensor로 불러오기 위해
    '''
    for batch_idx, batch_data in enumerate(training_data_loader, start=1):
    # batch_data = (input[batch_idx], target[batch_idx], blur_img[batch_idx])
    # batch_idx = 세개의 mini-batch의 출력 이미지 set의 index
    # enumerate({list}, number) 로 사용하면 interation 이 0 이 아니라 number 부터 시작 함
        _, target, bicubic = Variable(batch_data[0]), Variable(batch_data[1]), Variable(batch_data[2])
        # autograd.Variable({tensor}) 라고 쓰면, {tensor} 를 불러옴 
        if cuda:
            # input = input.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])

        optimizer.zero_grad()
        # gradient 를 0으로 초기화
        t0 = time.time()
        prediction = model(bicubic)

        loss = criterion(prediction, target)
        epoch_loss += loss.data
        # 해당 mini-batch 에서 loss function 값
        loss.backward()
        # loss 를 가지고 gradient 계산
        optimizer.step()
        # 각 layer들의 weights 갱신
        t1 = time.time()

        print("===> Epoch[{}]({}/{}): Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, batch_idx, len(training_data_loader), loss.data, (t1 - t0)))
        # t1-t0 = 한 mini-batch 연산에 걸린 시간

    print("===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(training_data_loader)))
    
    '''
    Model 의 Checkpoint 저장하기 for test(evaluation)
    '''
    if (epoch) % (opt.snapshots) == 0:
      model_out_path = opt.save_folder+"Compare_SRCNN_epoch_{}.pth".format(epoch)
      torch.save({'epoch' : epoch,
              'model_state_dict' : model.state_dict(),
                'loss' : loss.data}, model_out_path)
      print("Checkpoint saved to {}".format(model_out_path))

    '''
    Tensorboard 에 매 epoch 마다 loss 저장하기
    '''
    writer.add_scalar('Epoch Loss', epoch_loss / len(training_data_loader), epoch )
    # 그래프의 가로축 = epoch, 세로 축 = epoch_loss / len(training_data_loader)

    loss_list.append(epoch_loss / len(training_data_loader))

if __name__ == '__main__':
    for epoch in range(opt.start_epoch, opt.nEpochs + 1):
        train(epoch)

writer.close()
# writer 가 더이상 필요하지 않으므로 닫아준다

print('Finished Training')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ===> Loading datasets
# ===> Building model  WCNN
# ===> Weight Initialization
# {'batchSize': 32, 'lr': 0.01, 'upscale_factor': 2, 'patch_size': 32, 'start_epoch': 1, 'nEpochs': 100, 'snapshots': 10, 'data_dir': '/content/gdrive/My Drive/졸업논문/data_800개/train', 'hr_train_dataset': 'DIV2K_train_HR', 'model_type': 'WCNN', 'save_folder': '/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/', 'pretrained_sr': None, 'pretrained': False, 'data_augmentation': False, 'gpu_mode': True, 'threads': 1, 'gpus': 1}
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# 2021-05-11 17:53:24.438098: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# usage: tensorboard [-h] [--helpfull] {serve,dev} ...
# tensorboard: error: invalid choice: 'tensorboard' (choose from 'serve', 'dev')
# ===> Epoch[1](1/25): Loss: 0.9421 || Timer: 0.0077 sec.
# ===> Epoch[1](2/25): Loss: 186.4216 || Timer: 0.0036 sec.
# ===> Epoch[1](3/25): Loss: 1.6352 || Timer: 0.0032 sec.
# ===> Epoch[1](4/25): Loss: 0.2085 || Timer: 0.0041 sec.
# ===> Epoch[1](5/25): Loss: 0.2870 || Timer: 0.0032 sec.
# ===> Epoch[1](6/25): Loss: 0.3025 || Timer: 0.0035 sec.
# ===> Epoch[1](7/25): Loss: 0.2718 || Timer: 0.0030 sec.
# ===> Epoch[1](8/25): Loss: 0.2242 || Timer: 0.0032 sec.
# ===> Epoch[1](9/25): Loss: 0.2041 || Timer: 0.0033 sec.
# ===> Epoch[1](10/25): Loss: 0.1975 || Timer: 0.0034 sec.
# ===> Epoch[1](11/25): Loss: 0.2239 || Timer: 0.0039 sec.
# ===> Epoch[1](12/25): Loss: 0.1940 || Timer: 0.0040 sec.
# ===> Epoch[1](13/25): Loss: 0.1938 || Timer: 0.0034 sec.
# ===> Epoch[1](14/25): Loss: 0.1004 || Timer: 0.0034 sec.
# ===> Epoch[1](15/25): Loss: 0.1405 || Timer: 0.0034 sec.
# ===> Epoch[1](16/25): Loss: 0.0862 || Timer: 0.0041 sec.
# ===> Epoch[1](17/25): Loss: 0.0917 || Timer: 0.0032 sec.
# ===> Epoch[1](18/25): Loss: 0.0935 || Timer: 0.0030 sec.
# ===> Epoch[1](19/25): Loss: 0.0981 || Timer: 0.0032 sec.
# ===> Epoch[1](20/25): Loss: 0.1225 || Timer: 0.0035 sec.
# ===> Epoch[1](21/25): Loss: 0.1012 || Timer: 0.0037 sec.
# ===> Epoch[1](22/25): Loss: 0.1113 || Timer: 0.0040 sec.
# ===> Epoch[1](23/25): Loss: 0.1199 || Timer: 0.0030 sec.
# ===> Epoch[1](24/25): Loss: 0.0952 || Timer: 0.0041 sec.
# ===> Epoch[1](25/25): Loss: 0.0893 || Timer: 0.0033 sec.
# ===> Epoch 1 Complete: Avg. Loss: 7.7022
# ===> Epoch[2](1/25): Loss: 0.0936 || Timer: 0.0058 sec.
# ===> Epoch[2](2/25): Loss: 0.1018 || Timer: 0.0034 sec.
# ===> Epoch[2](3/25): Loss: 0.0654 || Timer: 0.0040 sec.
# ===> Epoch[2](4/25): Loss: 0.0930 || Timer: 0.0038 sec.
# ===> Epoch[2](5/25): Loss: 0.0852 || Timer: 0.0031 sec.
# ===> Epoch[2](6/25): Loss: 0.1028 || Timer: 0.0034 sec.
# ===> Epoch[2](7/25): Loss: 0.0873 || Timer: 0.0038 sec.
# ===> Epoch[2](8/25): Loss: 0.0927 || Timer: 0.0050 sec.
# ===> Epoch[2](9/25): Loss: 0.0867 || Timer: 0.0036 sec.
# ===> Epoch[2](10/25): Loss: 0.0934 || Timer: 0.0038 sec.
# ===> Epoch[2](11/25): Loss: 0.0859 || Timer: 0.0033 sec.
# ===> Epoch[2](12/25): Loss: 0.0646 || Timer: 0.0035 sec.
# ===> Epoch[2](13/25): Loss: 0.0883 || Timer: 0.0031 sec.
# ===> Epoch[2](14/25): Loss: 0.0772 || Timer: 0.0034 sec.
# ===> Epoch[2](15/25): Loss: 0.0902 || Timer: 0.0032 sec.
# ===> Epoch[2](16/25): Loss: 0.0943 || Timer: 0.0036 sec.
# ===> Epoch[2](17/25): Loss: 0.0994 || Timer: 0.0039 sec.
# ===> Epoch[2](18/25): Loss: 0.0902 || Timer: 0.0042 sec.
# ===> Epoch[2](19/25): Loss: 0.0740 || Timer: 0.0041 sec.
# ===> Epoch[2](20/25): Loss: 0.0825 || Timer: 0.0031 sec.
# ===> Epoch[2](21/25): Loss: 0.0815 || Timer: 0.0034 sec.
# ===> Epoch[2](22/25): Loss: 0.0873 || Timer: 0.0036 sec.
# ===> Epoch[2](23/25): Loss: 0.0741 || Timer: 0.0035 sec.
# ===> Epoch[2](24/25): Loss: 0.0783 || Timer: 0.0040 sec.
# ===> Epoch[2](25/25): Loss: 0.0800 || Timer: 0.0031 sec.
# ===> Epoch 2 Complete: Avg. Loss: 0.0860
# ===> Epoch[3](1/25): Loss: 0.0724 || Timer: 0.0051 sec.
# ===> Epoch[3](2/25): Loss: 0.0729 || Timer: 0.0041 sec.
# ===> Epoch[3](3/25): Loss: 0.0771 || Timer: 0.0042 sec.
# ===> Epoch[3](4/25): Loss: 0.0870 || Timer: 0.0036 sec.
# ===> Epoch[3](5/25): Loss: 0.0817 || Timer: 0.0043 sec.
# ===> Epoch[3](6/25): Loss: 0.0979 || Timer: 0.0040 sec.
# ===> Epoch[3](7/25): Loss: 0.0821 || Timer: 0.0040 sec.
# ===> Epoch[3](8/25): Loss: 0.0916 || Timer: 0.0040 sec.
# ===> Epoch[3](9/25): Loss: 0.0712 || Timer: 0.0039 sec.
# ===> Epoch[3](10/25): Loss: 0.0746 || Timer: 0.0029 sec.
# ===> Epoch[3](11/25): Loss: 0.0800 || Timer: 0.0031 sec.
# ===> Epoch[3](12/25): Loss: 0.0892 || Timer: 0.0040 sec.
# ===> Epoch[3](13/25): Loss: 0.0759 || Timer: 0.0046 sec.
# ===> Epoch[3](14/25): Loss: 0.0852 || Timer: 0.0036 sec.
# ===> Epoch[3](15/25): Loss: 0.0789 || Timer: 0.0037 sec.
# ===> Epoch[3](16/25): Loss: 0.0791 || Timer: 0.0039 sec.
# ===> Epoch[3](17/25): Loss: 0.0853 || Timer: 0.0029 sec.
# ===> Epoch[3](18/25): Loss: 0.0771 || Timer: 0.0038 sec.
# ===> Epoch[3](19/25): Loss: 0.0774 || Timer: 0.0032 sec.
# ===> Epoch[3](20/25): Loss: 0.0768 || Timer: 0.0044 sec.
# ===> Epoch[3](21/25): Loss: 0.0740 || Timer: 0.0035 sec.
# ===> Epoch[3](22/25): Loss: 0.0732 || Timer: 0.0034 sec.
# ===> Epoch[3](23/25): Loss: 0.1010 || Timer: 0.0032 sec.
# ===> Epoch[3](24/25): Loss: 0.0812 || Timer: 0.0032 sec.
# ===> Epoch[3](25/25): Loss: 0.0872 || Timer: 0.0030 sec.
# ===> Epoch 3 Complete: Avg. Loss: 0.0812
# ===> Epoch[4](1/25): Loss: 0.0940 || Timer: 0.0050 sec.
# ===> Epoch[4](2/25): Loss: 0.0696 || Timer: 0.0032 sec.
# ===> Epoch[4](3/25): Loss: 0.0822 || Timer: 0.0039 sec.
# ===> Epoch[4](4/25): Loss: 0.0820 || Timer: 0.0039 sec.
# ===> Epoch[4](5/25): Loss: 0.0990 || Timer: 0.0030 sec.
# ===> Epoch[4](6/25): Loss: 0.0883 || Timer: 0.0036 sec.
# ===> Epoch[4](7/25): Loss: 0.0815 || Timer: 0.0041 sec.
# ===> Epoch[4](8/25): Loss: 0.0907 || Timer: 0.0034 sec.
# ===> Epoch[4](9/25): Loss: 0.0687 || Timer: 0.0041 sec.
# ===> Epoch[4](10/25): Loss: 0.0905 || Timer: 0.0032 sec.
# ===> Epoch[4](11/25): Loss: 0.0881 || Timer: 0.0039 sec.
# ===> Epoch[4](12/25): Loss: 0.0743 || Timer: 0.0031 sec.
# ===> Epoch[4](13/25): Loss: 0.0752 || Timer: 0.0035 sec.
# ===> Epoch[4](14/25): Loss: 0.0854 || Timer: 0.0029 sec.
# ===> Epoch[4](15/25): Loss: 0.0966 || Timer: 0.0035 sec.
# ===> Epoch[4](16/25): Loss: 0.0841 || Timer: 0.0037 sec.
# ===> Epoch[4](17/25): Loss: 0.0789 || Timer: 0.0033 sec.
# ===> Epoch[4](18/25): Loss: 0.0798 || Timer: 0.0035 sec.
# ===> Epoch[4](19/25): Loss: 0.1015 || Timer: 0.0037 sec.
# ===> Epoch[4](20/25): Loss: 0.0867 || Timer: 0.0037 sec.
# ===> Epoch[4](21/25): Loss: 0.0758 || Timer: 0.0032 sec.
# ===> Epoch[4](22/25): Loss: 0.0736 || Timer: 0.0034 sec.
# ===> Epoch[4](23/25): Loss: 0.0708 || Timer: 0.0039 sec.
# ===> Epoch[4](24/25): Loss: 0.0731 || Timer: 0.0034 sec.
# ===> Epoch[4](25/25): Loss: 0.0844 || Timer: 0.0033 sec.
# ===> Epoch 4 Complete: Avg. Loss: 0.0830
# ===> Epoch[5](1/25): Loss: 0.0771 || Timer: 0.0061 sec.
# ===> Epoch[5](2/25): Loss: 0.0796 || Timer: 0.0032 sec.
# ===> Epoch[5](3/25): Loss: 0.0760 || Timer: 0.0032 sec.
# ===> Epoch[5](4/25): Loss: 0.0881 || Timer: 0.0040 sec.
# ===> Epoch[5](5/25): Loss: 0.0829 || Timer: 0.0035 sec.
# ===> Epoch[5](6/25): Loss: 0.0866 || Timer: 0.0033 sec.
# ===> Epoch[5](7/25): Loss: 0.0722 || Timer: 0.0037 sec.
# ===> Epoch[5](8/25): Loss: 0.0695 || Timer: 0.0032 sec.
# ===> Epoch[5](9/25): Loss: 0.0703 || Timer: 0.0030 sec.
# ===> Epoch[5](10/25): Loss: 0.0867 || Timer: 0.0032 sec.
# ===> Epoch[5](11/25): Loss: 0.0817 || Timer: 0.0031 sec.
# ===> Epoch[5](12/25): Loss: 0.0789 || Timer: 0.0033 sec.
# ===> Epoch[5](13/25): Loss: 0.0764 || Timer: 0.0037 sec.
# ===> Epoch[5](14/25): Loss: 0.0634 || Timer: 0.0040 sec.
# ===> Epoch[5](15/25): Loss: 0.0912 || Timer: 0.0041 sec.
# ===> Epoch[5](16/25): Loss: 0.0795 || Timer: 0.0035 sec.
# ===> Epoch[5](17/25): Loss: 0.0954 || Timer: 0.0033 sec.
# ===> Epoch[5](18/25): Loss: 0.0873 || Timer: 0.0040 sec.
# ===> Epoch[5](19/25): Loss: 0.0691 || Timer: 0.0031 sec.
# ===> Epoch[5](20/25): Loss: 0.0830 || Timer: 0.0030 sec.
# ===> Epoch[5](21/25): Loss: 0.0827 || Timer: 0.0031 sec.
# ===> Epoch[5](22/25): Loss: 0.0913 || Timer: 0.0031 sec.
# ===> Epoch[5](23/25): Loss: 0.0892 || Timer: 0.0030 sec.
# ===> Epoch[5](24/25): Loss: 0.0815 || Timer: 0.0028 sec.
# ===> Epoch[5](25/25): Loss: 0.0905 || Timer: 0.0026 sec.
# ===> Epoch 5 Complete: Avg. Loss: 0.0812
# ===> Epoch[6](1/25): Loss: 0.0865 || Timer: 0.0058 sec.
# ===> Epoch[6](2/25): Loss: 0.0759 || Timer: 0.0040 sec.
# ===> Epoch[6](3/25): Loss: 0.0737 || Timer: 0.0038 sec.
# ===> Epoch[6](4/25): Loss: 0.0839 || Timer: 0.0039 sec.
# ===> Epoch[6](5/25): Loss: 0.0900 || Timer: 0.0030 sec.
# ===> Epoch[6](6/25): Loss: 0.0693 || Timer: 0.0040 sec.
# ===> Epoch[6](7/25): Loss: 0.0591 || Timer: 0.0035 sec.
# ===> Epoch[6](8/25): Loss: 0.0644 || Timer: 0.0034 sec.
# ===> Epoch[6](9/25): Loss: 0.0750 || Timer: 0.0043 sec.
# ===> Epoch[6](10/25): Loss: 0.0738 || Timer: 0.0040 sec.
# ===> Epoch[6](11/25): Loss: 0.0832 || Timer: 0.0035 sec.
# ===> Epoch[6](12/25): Loss: 0.0808 || Timer: 0.0043 sec.
# ===> Epoch[6](13/25): Loss: 0.0720 || Timer: 0.0042 sec.
# ===> Epoch[6](14/25): Loss: 0.0899 || Timer: 0.0034 sec.
# ===> Epoch[6](15/25): Loss: 0.0914 || Timer: 0.0036 sec.
# ===> Epoch[6](16/25): Loss: 0.0864 || Timer: 0.0036 sec.
# ===> Epoch[6](17/25): Loss: 0.0725 || Timer: 0.0037 sec.
# ===> Epoch[6](18/25): Loss: 0.0984 || Timer: 0.0040 sec.
# ===> Epoch[6](19/25): Loss: 0.0727 || Timer: 0.0034 sec.
# ===> Epoch[6](20/25): Loss: 0.0626 || Timer: 0.0051 sec.
# ===> Epoch[6](21/25): Loss: 0.0848 || Timer: 0.0032 sec.
# ===> Epoch[6](22/25): Loss: 0.0898 || Timer: 0.0037 sec.
# ===> Epoch[6](23/25): Loss: 0.0923 || Timer: 0.0033 sec.
# ===> Epoch[6](24/25): Loss: 0.0762 || Timer: 0.0038 sec.
# ===> Epoch[6](25/25): Loss: 0.0714 || Timer: 0.0030 sec.
# ===> Epoch 6 Complete: Avg. Loss: 0.0790
# ===> Epoch[7](1/25): Loss: 0.0843 || Timer: 0.0053 sec.
# ===> Epoch[7](2/25): Loss: 0.1032 || Timer: 0.0034 sec.
# ===> Epoch[7](3/25): Loss: 0.0785 || Timer: 0.0041 sec.
# ===> Epoch[7](4/25): Loss: 0.0606 || Timer: 0.0041 sec.
# ===> Epoch[7](5/25): Loss: 0.0718 || Timer: 0.0039 sec.
# ===> Epoch[7](6/25): Loss: 0.0793 || Timer: 0.0038 sec.
# ===> Epoch[7](7/25): Loss: 0.0882 || Timer: 0.0031 sec.
# ===> Epoch[7](8/25): Loss: 0.0870 || Timer: 0.0040 sec.
# ===> Epoch[7](9/25): Loss: 0.0961 || Timer: 0.0039 sec.
# ===> Epoch[7](10/25): Loss: 0.0878 || Timer: 0.0036 sec.
# ===> Epoch[7](11/25): Loss: 0.0768 || Timer: 0.0032 sec.
# ===> Epoch[7](12/25): Loss: 0.0815 || Timer: 0.0032 sec.
# ===> Epoch[7](13/25): Loss: 0.0923 || Timer: 0.0038 sec.
# ===> Epoch[7](14/25): Loss: 0.0908 || Timer: 0.0030 sec.
# ===> Epoch[7](15/25): Loss: 0.0736 || Timer: 0.0032 sec.
# ===> Epoch[7](16/25): Loss: 0.0943 || Timer: 0.0029 sec.
# ===> Epoch[7](17/25): Loss: 0.0762 || Timer: 0.0031 sec.
# ===> Epoch[7](18/25): Loss: 0.0749 || Timer: 0.0034 sec.
# ===> Epoch[7](19/25): Loss: 0.0741 || Timer: 0.0032 sec.
# ===> Epoch[7](20/25): Loss: 0.0801 || Timer: 0.0044 sec.
# ===> Epoch[7](21/25): Loss: 0.0683 || Timer: 0.0038 sec.
# ===> Epoch[7](22/25): Loss: 0.0981 || Timer: 0.0037 sec.
# ===> Epoch[7](23/25): Loss: 0.1102 || Timer: 0.0029 sec.
# ===> Epoch[7](24/25): Loss: 0.0567 || Timer: 0.0031 sec.
# ===> Epoch[7](25/25): Loss: 0.0617 || Timer: 0.0031 sec.
# ===> Epoch 7 Complete: Avg. Loss: 0.0819
# ===> Epoch[8](1/25): Loss: 0.0906 || Timer: 0.0065 sec.
# ===> Epoch[8](2/25): Loss: 0.0894 || Timer: 0.0037 sec.
# ===> Epoch[8](3/25): Loss: 0.0970 || Timer: 0.0046 sec.
# ===> Epoch[8](4/25): Loss: 0.0739 || Timer: 0.0046 sec.
# ===> Epoch[8](5/25): Loss: 0.0850 || Timer: 0.0032 sec.
# ===> Epoch[8](6/25): Loss: 0.0875 || Timer: 0.0042 sec.
# ===> Epoch[8](7/25): Loss: 0.0648 || Timer: 0.0034 sec.
# ===> Epoch[8](8/25): Loss: 0.0810 || Timer: 0.0032 sec.
# ===> Epoch[8](9/25): Loss: 0.0754 || Timer: 0.0030 sec.
# ===> Epoch[8](10/25): Loss: 0.0868 || Timer: 0.0032 sec.
# ===> Epoch[8](11/25): Loss: 0.0672 || Timer: 0.0034 sec.
# ===> Epoch[8](12/25): Loss: 0.0890 || Timer: 0.0031 sec.
# ===> Epoch[8](13/25): Loss: 0.0710 || Timer: 0.0040 sec.
# ===> Epoch[8](14/25): Loss: 0.0663 || Timer: 0.0038 sec.
# ===> Epoch[8](15/25): Loss: 0.0816 || Timer: 0.0031 sec.
# ===> Epoch[8](16/25): Loss: 0.0877 || Timer: 0.0029 sec.
# ===> Epoch[8](17/25): Loss: 0.0895 || Timer: 0.0034 sec.
# ===> Epoch[8](18/25): Loss: 0.0838 || Timer: 0.0040 sec.
# ===> Epoch[8](19/25): Loss: 0.0769 || Timer: 0.0033 sec.
# ===> Epoch[8](20/25): Loss: 0.0726 || Timer: 0.0037 sec.
# ===> Epoch[8](21/25): Loss: 0.0727 || Timer: 0.0037 sec.
# ===> Epoch[8](22/25): Loss: 0.0789 || Timer: 0.0035 sec.
# ===> Epoch[8](23/25): Loss: 0.0873 || Timer: 0.0043 sec.
# ===> Epoch[8](24/25): Loss: 0.0791 || Timer: 0.0033 sec.
# ===> Epoch[8](25/25): Loss: 0.0802 || Timer: 0.0030 sec.
# ===> Epoch 8 Complete: Avg. Loss: 0.0806
# ===> Epoch[9](1/25): Loss: 0.0710 || Timer: 0.0072 sec.
# ===> Epoch[9](2/25): Loss: 0.0959 || Timer: 0.0032 sec.
# ===> Epoch[9](3/25): Loss: 0.0790 || Timer: 0.0039 sec.
# ===> Epoch[9](4/25): Loss: 0.0822 || Timer: 0.0048 sec.
# ===> Epoch[9](5/25): Loss: 0.0830 || Timer: 0.0031 sec.
# ===> Epoch[9](6/25): Loss: 0.0712 || Timer: 0.0037 sec.
# ===> Epoch[9](7/25): Loss: 0.0825 || Timer: 0.0035 sec.
# ===> Epoch[9](8/25): Loss: 0.0741 || Timer: 0.0044 sec.
# ===> Epoch[9](9/25): Loss: 0.0752 || Timer: 0.0038 sec.
# ===> Epoch[9](10/25): Loss: 0.0673 || Timer: 0.0040 sec.
# ===> Epoch[9](11/25): Loss: 0.0696 || Timer: 0.0039 sec.
# ===> Epoch[9](12/25): Loss: 0.0868 || Timer: 0.0041 sec.
# ===> Epoch[9](13/25): Loss: 0.0886 || Timer: 0.0031 sec.
# ===> Epoch[9](14/25): Loss: 0.1010 || Timer: 0.0032 sec.
# ===> Epoch[9](15/25): Loss: 0.0653 || Timer: 0.0041 sec.
# ===> Epoch[9](16/25): Loss: 0.0857 || Timer: 0.0041 sec.
# ===> Epoch[9](17/25): Loss: 0.0772 || Timer: 0.0039 sec.
# ===> Epoch[9](18/25): Loss: 0.0724 || Timer: 0.0034 sec.
# ===> Epoch[9](19/25): Loss: 0.0947 || Timer: 0.0029 sec.
# ===> Epoch[9](20/25): Loss: 0.0802 || Timer: 0.0031 sec.
# ===> Epoch[9](21/25): Loss: 0.0710 || Timer: 0.0030 sec.
# ===> Epoch[9](22/25): Loss: 0.1016 || Timer: 0.0031 sec.
# ===> Epoch[9](23/25): Loss: 0.0753 || Timer: 0.0038 sec.
# ===> Epoch[9](24/25): Loss: 0.0734 || Timer: 0.0036 sec.
# ===> Epoch[9](25/25): Loss: 0.0773 || Timer: 0.0030 sec.
# ===> Epoch 9 Complete: Avg. Loss: 0.0800
# ===> Epoch[10](1/25): Loss: 0.0986 || Timer: 0.0059 sec.
# ===> Epoch[10](2/25): Loss: 0.0913 || Timer: 0.0035 sec.
# ===> Epoch[10](3/25): Loss: 0.0787 || Timer: 0.0038 sec.
# ===> Epoch[10](4/25): Loss: 0.0765 || Timer: 0.0034 sec.
# ===> Epoch[10](5/25): Loss: 0.0914 || Timer: 0.0031 sec.
# ===> Epoch[10](6/25): Loss: 0.0971 || Timer: 0.0034 sec.
# ===> Epoch[10](7/25): Loss: 0.0776 || Timer: 0.0040 sec.
# ===> Epoch[10](8/25): Loss: 0.0891 || Timer: 0.0039 sec.
# ===> Epoch[10](9/25): Loss: 0.0954 || Timer: 0.0032 sec.
# ===> Epoch[10](10/25): Loss: 0.0646 || Timer: 0.0037 sec.
# ===> Epoch[10](11/25): Loss: 0.0715 || Timer: 0.0038 sec.
# ===> Epoch[10](12/25): Loss: 0.0657 || Timer: 0.0032 sec.
# ===> Epoch[10](13/25): Loss: 0.0845 || Timer: 0.0034 sec.
# ===> Epoch[10](14/25): Loss: 0.0650 || Timer: 0.0033 sec.
# ===> Epoch[10](15/25): Loss: 0.0798 || Timer: 0.0031 sec.
# ===> Epoch[10](16/25): Loss: 0.0804 || Timer: 0.0039 sec.
# ===> Epoch[10](17/25): Loss: 0.0673 || Timer: 0.0034 sec.
# ===> Epoch[10](18/25): Loss: 0.0928 || Timer: 0.0030 sec.
# ===> Epoch[10](19/25): Loss: 0.0872 || Timer: 0.0039 sec.
# ===> Epoch[10](20/25): Loss: 0.0645 || Timer: 0.0031 sec.
# ===> Epoch[10](21/25): Loss: 0.0851 || Timer: 0.0033 sec.
# ===> Epoch[10](22/25): Loss: 0.0815 || Timer: 0.0037 sec.
# ===> Epoch[10](23/25): Loss: 0.0714 || Timer: 0.0042 sec.
# ===> Epoch[10](24/25): Loss: 0.0757 || Timer: 0.0039 sec.
# ===> Epoch[10](25/25): Loss: 0.0759 || Timer: 0.0027 sec.
# ===> Epoch 10 Complete: Avg. Loss: 0.0803
# Checkpoint saved to /content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_10.pth
# ===> Epoch[11](1/25): Loss: 0.0728 || Timer: 0.0056 sec.
# ===> Epoch[11](2/25): Loss: 0.0651 || Timer: 0.0038 sec.
# ===> Epoch[11](3/25): Loss: 0.0884 || Timer: 0.0044 sec.
# ===> Epoch[11](4/25): Loss: 0.0855 || Timer: 0.0040 sec.
# ===> Epoch[11](5/25): Loss: 0.0849 || Timer: 0.0032 sec.
# ===> Epoch[11](6/25): Loss: 0.0822 || Timer: 0.0038 sec.
# ===> Epoch[11](7/25): Loss: 0.0923 || Timer: 0.0040 sec.
# ===> Epoch[11](8/25): Loss: 0.0611 || Timer: 0.0033 sec.
# ===> Epoch[11](9/25): Loss: 0.0768 || Timer: 0.0039 sec.
# ===> Epoch[11](10/25): Loss: 0.0835 || Timer: 0.0034 sec.
# ===> Epoch[11](11/25): Loss: 0.0776 || Timer: 0.0034 sec.
# ===> Epoch[11](12/25): Loss: 0.0772 || Timer: 0.0038 sec.
# ===> Epoch[11](13/25): Loss: 0.0881 || Timer: 0.0030 sec.
# ===> Epoch[11](14/25): Loss: 0.0786 || Timer: 0.0030 sec.
# ===> Epoch[11](15/25): Loss: 0.0941 || Timer: 0.0038 sec.
# ===> Epoch[11](16/25): Loss: 0.0653 || Timer: 0.0033 sec.
# ===> Epoch[11](17/25): Loss: 0.0937 || Timer: 0.0031 sec.
# ===> Epoch[11](18/25): Loss: 0.0870 || Timer: 0.0040 sec.
# ===> Epoch[11](19/25): Loss: 0.0723 || Timer: 0.0032 sec.
# ===> Epoch[11](20/25): Loss: 0.0830 || Timer: 0.0038 sec.
# ===> Epoch[11](21/25): Loss: 0.0816 || Timer: 0.0032 sec.
# ===> Epoch[11](22/25): Loss: 0.0950 || Timer: 0.0031 sec.
# ===> Epoch[11](23/25): Loss: 0.0736 || Timer: 0.0038 sec.
# ===> Epoch[11](24/25): Loss: 0.0811 || Timer: 0.0035 sec.
# ===> Epoch[11](25/25): Loss: 0.1003 || Timer: 0.0030 sec.
# ===> Epoch 11 Complete: Avg. Loss: 0.0816
# ===> Epoch[12](1/25): Loss: 0.0741 || Timer: 0.0054 sec.
# ===> Epoch[12](2/25): Loss: 0.0857 || Timer: 0.0037 sec.
# ===> Epoch[12](3/25): Loss: 0.0863 || Timer: 0.0034 sec.
# ===> Epoch[12](4/25): Loss: 0.0682 || Timer: 0.0031 sec.
# ===> Epoch[12](5/25): Loss: 0.0782 || Timer: 0.0031 sec.
# ===> Epoch[12](6/25): Loss: 0.0838 || Timer: 0.0042 sec.
# ===> Epoch[12](7/25): Loss: 0.0800 || Timer: 0.0034 sec.
# ===> Epoch[12](8/25): Loss: 0.0767 || Timer: 0.0038 sec.
# ===> Epoch[12](9/25): Loss: 0.0768 || Timer: 0.0042 sec.
# ===> Epoch[12](10/25): Loss: 0.0700 || Timer: 0.0038 sec.
# ===> Epoch[12](11/25): Loss: 0.0944 || Timer: 0.0039 sec.
# ===> Epoch[12](12/25): Loss: 0.0921 || Timer: 0.0032 sec.
# ===> Epoch[12](13/25): Loss: 0.0703 || Timer: 0.0040 sec.
# ===> Epoch[12](14/25): Loss: 0.0755 || Timer: 0.0036 sec.
# ===> Epoch[12](15/25): Loss: 0.0827 || Timer: 0.0039 sec.
# ===> Epoch[12](16/25): Loss: 0.0827 || Timer: 0.0039 sec.
# ===> Epoch[12](17/25): Loss: 0.0776 || Timer: 0.0031 sec.
# ===> Epoch[12](18/25): Loss: 0.0817 || Timer: 0.0036 sec.
# ===> Epoch[12](19/25): Loss: 0.0709 || Timer: 0.0033 sec.
# ===> Epoch[12](20/25): Loss: 0.0829 || Timer: 0.0029 sec.
# ===> Epoch[12](21/25): Loss: 0.0869 || Timer: 0.0033 sec.
# ===> Epoch[12](22/25): Loss: 0.0849 || Timer: 0.0031 sec.
# ===> Epoch[12](23/25): Loss: 0.0862 || Timer: 0.0042 sec.
# ===> Epoch[12](24/25): Loss: 0.0730 || Timer: 0.0031 sec.
# ===> Epoch[12](25/25): Loss: 0.1031 || Timer: 0.0030 sec.
# ===> Epoch 12 Complete: Avg. Loss: 0.0810
# ===> Epoch[13](1/25): Loss: 0.0938 || Timer: 0.0058 sec.
# ===> Epoch[13](2/25): Loss: 0.0630 || Timer: 0.0040 sec.
# ===> Epoch[13](3/25): Loss: 0.0782 || Timer: 0.0039 sec.
# ===> Epoch[13](4/25): Loss: 0.0881 || Timer: 0.0036 sec.
# ===> Epoch[13](5/25): Loss: 0.0914 || Timer: 0.0031 sec.
# ===> Epoch[13](6/25): Loss: 0.0862 || Timer: 0.0039 sec.
# ===> Epoch[13](7/25): Loss: 0.0840 || Timer: 0.0039 sec.
# ===> Epoch[13](8/25): Loss: 0.0789 || Timer: 0.0031 sec.
# ===> Epoch[13](9/25): Loss: 0.0823 || Timer: 0.0031 sec.
# ===> Epoch[13](10/25): Loss: 0.0907 || Timer: 0.0036 sec.
# ===> Epoch[13](11/25): Loss: 0.0839 || Timer: 0.0031 sec.
# ===> Epoch[13](12/25): Loss: 0.0812 || Timer: 0.0031 sec.
# ===> Epoch[13](13/25): Loss: 0.0666 || Timer: 0.0032 sec.
# ===> Epoch[13](14/25): Loss: 0.0789 || Timer: 0.0036 sec.
# ===> Epoch[13](15/25): Loss: 0.0651 || Timer: 0.0032 sec.
# ===> Epoch[13](16/25): Loss: 0.0776 || Timer: 0.0040 sec.
# ===> Epoch[13](17/25): Loss: 0.0690 || Timer: 0.0031 sec.
# ===> Epoch[13](18/25): Loss: 0.0691 || Timer: 0.0032 sec.
# ===> Epoch[13](19/25): Loss: 0.0673 || Timer: 0.0029 sec.
# ===> Epoch[13](20/25): Loss: 0.0644 || Timer: 0.0034 sec.
# ===> Epoch[13](21/25): Loss: 0.0793 || Timer: 0.0030 sec.
# ===> Epoch[13](22/25): Loss: 0.0728 || Timer: 0.0034 sec.
# ===> Epoch[13](23/25): Loss: 0.0749 || Timer: 0.0038 sec.
# ===> Epoch[13](24/25): Loss: 0.0743 || Timer: 0.0034 sec.
# ===> Epoch[13](25/25): Loss: 0.0700 || Timer: 0.0030 sec.
# ===> Epoch 13 Complete: Avg. Loss: 0.0772
# ===> Epoch[14](1/25): Loss: 0.0860 || Timer: 0.0058 sec.
# ===> Epoch[14](2/25): Loss: 0.0962 || Timer: 0.0041 sec.
# ===> Epoch[14](3/25): Loss: 0.0796 || Timer: 0.0031 sec.
# ===> Epoch[14](4/25): Loss: 0.0747 || Timer: 0.0032 sec.
# ===> Epoch[14](5/25): Loss: 0.0906 || Timer: 0.0040 sec.
# ===> Epoch[14](6/25): Loss: 0.0919 || Timer: 0.0042 sec.
# ===> Epoch[14](7/25): Loss: 0.0674 || Timer: 0.0041 sec.
# ===> Epoch[14](8/25): Loss: 0.0769 || Timer: 0.0043 sec.
# ===> Epoch[14](9/25): Loss: 0.0861 || Timer: 0.0035 sec.
# ===> Epoch[14](10/25): Loss: 0.0714 || Timer: 0.0041 sec.
# ===> Epoch[14](11/25): Loss: 0.0919 || Timer: 0.0041 sec.
# ===> Epoch[14](12/25): Loss: 0.0864 || Timer: 0.0032 sec.
# ===> Epoch[14](13/25): Loss: 0.0759 || Timer: 0.0039 sec.
# ===> Epoch[14](14/25): Loss: 0.0789 || Timer: 0.0041 sec.
# ===> Epoch[14](15/25): Loss: 0.0748 || Timer: 0.0033 sec.
# ===> Epoch[14](16/25): Loss: 0.0819 || Timer: 0.0035 sec.
# ===> Epoch[14](17/25): Loss: 0.0796 || Timer: 0.0039 sec.
# ===> Epoch[14](18/25): Loss: 0.0690 || Timer: 0.0030 sec.
# ===> Epoch[14](19/25): Loss: 0.0906 || Timer: 0.0038 sec.
# ===> Epoch[14](20/25): Loss: 0.0719 || Timer: 0.0035 sec.
# ===> Epoch[14](21/25): Loss: 0.0910 || Timer: 0.0031 sec.
# ===> Epoch[14](22/25): Loss: 0.0916 || Timer: 0.0043 sec.
# ===> Epoch[14](23/25): Loss: 0.0946 || Timer: 0.0030 sec.
# ===> Epoch[14](24/25): Loss: 0.0834 || Timer: 0.0033 sec.
# ===> Epoch[14](25/25): Loss: 0.0896 || Timer: 0.0032 sec.
# ===> Epoch 14 Complete: Avg. Loss: 0.0829
# ===> Epoch[15](1/25): Loss: 0.0970 || Timer: 0.0067 sec.
# ===> Epoch[15](2/25): Loss: 0.0679 || Timer: 0.0039 sec.
# ===> Epoch[15](3/25): Loss: 0.0929 || Timer: 0.0037 sec.
# ===> Epoch[15](4/25): Loss: 0.0979 || Timer: 0.0035 sec.
# ===> Epoch[15](5/25): Loss: 0.0735 || Timer: 0.0040 sec.
# ===> Epoch[15](6/25): Loss: 0.0732 || Timer: 0.0039 sec.
# ===> Epoch[15](7/25): Loss: 0.0930 || Timer: 0.0033 sec.
# ===> Epoch[15](8/25): Loss: 0.0739 || Timer: 0.0029 sec.
# ===> Epoch[15](9/25): Loss: 0.0769 || Timer: 0.0038 sec.
# ===> Epoch[15](10/25): Loss: 0.0816 || Timer: 0.0037 sec.
# ===> Epoch[15](11/25): Loss: 0.0691 || Timer: 0.0033 sec.
# ===> Epoch[15](12/25): Loss: 0.0873 || Timer: 0.0033 sec.
# ===> Epoch[15](13/25): Loss: 0.0703 || Timer: 0.0039 sec.
# ===> Epoch[15](14/25): Loss: 0.0807 || Timer: 0.0040 sec.
# ===> Epoch[15](15/25): Loss: 0.0794 || Timer: 0.0030 sec.
# ===> Epoch[15](16/25): Loss: 0.0692 || Timer: 0.0030 sec.
# ===> Epoch[15](17/25): Loss: 0.0801 || Timer: 0.0031 sec.
# ===> Epoch[15](18/25): Loss: 0.0805 || Timer: 0.0033 sec.
# ===> Epoch[15](19/25): Loss: 0.0909 || Timer: 0.0040 sec.
# ===> Epoch[15](20/25): Loss: 0.0892 || Timer: 0.0037 sec.
# ===> Epoch[15](21/25): Loss: 0.0921 || Timer: 0.0029 sec.
# ===> Epoch[15](22/25): Loss: 0.0979 || Timer: 0.0032 sec.
# ===> Epoch[15](23/25): Loss: 0.0809 || Timer: 0.0030 sec.
# ===> Epoch[15](24/25): Loss: 0.0654 || Timer: 0.0030 sec.
# ===> Epoch[15](25/25): Loss: 0.0657 || Timer: 0.0029 sec.
# ===> Epoch 15 Complete: Avg. Loss: 0.0811
# ===> Epoch[16](1/25): Loss: 0.0976 || Timer: 0.0049 sec.
# ===> Epoch[16](2/25): Loss: 0.0806 || Timer: 0.0032 sec.
# ===> Epoch[16](3/25): Loss: 0.0845 || Timer: 0.0034 sec.
# ===> Epoch[16](4/25): Loss: 0.0758 || Timer: 0.0033 sec.
# ===> Epoch[16](5/25): Loss: 0.0882 || Timer: 0.0035 sec.
# ===> Epoch[16](6/25): Loss: 0.0778 || Timer: 0.0030 sec.
# ===> Epoch[16](7/25): Loss: 0.0678 || Timer: 0.0030 sec.
# ===> Epoch[16](8/25): Loss: 0.0693 || Timer: 0.0034 sec.
# ===> Epoch[16](9/25): Loss: 0.0773 || Timer: 0.0034 sec.
# ===> Epoch[16](10/25): Loss: 0.0757 || Timer: 0.0038 sec.
# ===> Epoch[16](11/25): Loss: 0.0926 || Timer: 0.0033 sec.
# ===> Epoch[16](12/25): Loss: 0.0795 || Timer: 0.0038 sec.
# ===> Epoch[16](13/25): Loss: 0.0825 || Timer: 0.0039 sec.
# ===> Epoch[16](14/25): Loss: 0.0749 || Timer: 0.0038 sec.
# ===> Epoch[16](15/25): Loss: 0.0866 || Timer: 0.0043 sec.
# ===> Epoch[16](16/25): Loss: 0.0870 || Timer: 0.0035 sec.
# ===> Epoch[16](17/25): Loss: 0.0834 || Timer: 0.0031 sec.
# ===> Epoch[16](18/25): Loss: 0.0846 || Timer: 0.0039 sec.
# ===> Epoch[16](19/25): Loss: 0.0934 || Timer: 0.0029 sec.
# ===> Epoch[16](20/25): Loss: 0.0781 || Timer: 0.0036 sec.
# ===> Epoch[16](21/25): Loss: 0.0812 || Timer: 0.0039 sec.
# ===> Epoch[16](22/25): Loss: 0.0938 || Timer: 0.0031 sec.
# ===> Epoch[16](23/25): Loss: 0.0762 || Timer: 0.0038 sec.
# ===> Epoch[16](24/25): Loss: 0.0775 || Timer: 0.0056 sec.
# ===> Epoch[16](25/25): Loss: 0.0770 || Timer: 0.0029 sec.
# ===> Epoch 16 Complete: Avg. Loss: 0.0817
# ===> Epoch[17](1/25): Loss: 0.0743 || Timer: 0.0058 sec.
# ===> Epoch[17](2/25): Loss: 0.0876 || Timer: 0.0043 sec.
# ===> Epoch[17](3/25): Loss: 0.0847 || Timer: 0.0039 sec.
# ===> Epoch[17](4/25): Loss: 0.0759 || Timer: 0.0041 sec.
# ===> Epoch[17](5/25): Loss: 0.0839 || Timer: 0.0034 sec.
# ===> Epoch[17](6/25): Loss: 0.0825 || Timer: 0.0030 sec.
# ===> Epoch[17](7/25): Loss: 0.0918 || Timer: 0.0035 sec.
# ===> Epoch[17](8/25): Loss: 0.0884 || Timer: 0.0039 sec.
# ===> Epoch[17](9/25): Loss: 0.0677 || Timer: 0.0033 sec.
# ===> Epoch[17](10/25): Loss: 0.0855 || Timer: 0.0032 sec.
# ===> Epoch[17](11/25): Loss: 0.0866 || Timer: 0.0039 sec.
# ===> Epoch[17](12/25): Loss: 0.0829 || Timer: 0.0032 sec.
# ===> Epoch[17](13/25): Loss: 0.0915 || Timer: 0.0032 sec.
# ===> Epoch[17](14/25): Loss: 0.0984 || Timer: 0.0043 sec.
# ===> Epoch[17](15/25): Loss: 0.0787 || Timer: 0.0040 sec.
# ===> Epoch[17](16/25): Loss: 0.0872 || Timer: 0.0040 sec.
# ===> Epoch[17](17/25): Loss: 0.0838 || Timer: 0.0044 sec.
# ===> Epoch[17](18/25): Loss: 0.0838 || Timer: 0.0039 sec.
# ===> Epoch[17](19/25): Loss: 0.0578 || Timer: 0.0041 sec.
# ===> Epoch[17](20/25): Loss: 0.0789 || Timer: 0.0042 sec.
# ===> Epoch[17](21/25): Loss: 0.0797 || Timer: 0.0030 sec.
# ===> Epoch[17](22/25): Loss: 0.0713 || Timer: 0.0038 sec.
# ===> Epoch[17](23/25): Loss: 0.0774 || Timer: 0.0033 sec.
# ===> Epoch[17](24/25): Loss: 0.0791 || Timer: 0.0032 sec.
# ===> Epoch[17](25/25): Loss: 0.0810 || Timer: 0.0029 sec.
# ===> Epoch 17 Complete: Avg. Loss: 0.0816
# ===> Epoch[18](1/25): Loss: 0.0732 || Timer: 0.0052 sec.
# ===> Epoch[18](2/25): Loss: 0.0705 || Timer: 0.0040 sec.
# ===> Epoch[18](3/25): Loss: 0.0792 || Timer: 0.0033 sec.
# ===> Epoch[18](4/25): Loss: 0.0735 || Timer: 0.0041 sec.
# ===> Epoch[18](5/25): Loss: 0.0895 || Timer: 0.0033 sec.
# ===> Epoch[18](6/25): Loss: 0.0784 || Timer: 0.0036 sec.
# ===> Epoch[18](7/25): Loss: 0.0804 || Timer: 0.0041 sec.
# ===> Epoch[18](8/25): Loss: 0.0849 || Timer: 0.0031 sec.
# ===> Epoch[18](9/25): Loss: 0.0705 || Timer: 0.0044 sec.
# ===> Epoch[18](10/25): Loss: 0.0776 || Timer: 0.0030 sec.
# ===> Epoch[18](11/25): Loss: 0.0788 || Timer: 0.0031 sec.
# ===> Epoch[18](12/25): Loss: 0.0786 || Timer: 0.0037 sec.
# ===> Epoch[18](13/25): Loss: 0.0997 || Timer: 0.0038 sec.
# ===> Epoch[18](14/25): Loss: 0.0720 || Timer: 0.0031 sec.
# ===> Epoch[18](15/25): Loss: 0.0726 || Timer: 0.0035 sec.
# ===> Epoch[18](16/25): Loss: 0.0873 || Timer: 0.0040 sec.
# ===> Epoch[18](17/25): Loss: 0.0847 || Timer: 0.0036 sec.
# ===> Epoch[18](18/25): Loss: 0.0782 || Timer: 0.0032 sec.
# ===> Epoch[18](19/25): Loss: 0.0810 || Timer: 0.0029 sec.
# ===> Epoch[18](20/25): Loss: 0.0880 || Timer: 0.0038 sec.
# ===> Epoch[18](21/25): Loss: 0.1037 || Timer: 0.0032 sec.
# ===> Epoch[18](22/25): Loss: 0.0657 || Timer: 0.0034 sec.
# ===> Epoch[18](23/25): Loss: 0.0709 || Timer: 0.0031 sec.
# ===> Epoch[18](24/25): Loss: 0.0660 || Timer: 0.0032 sec.
# ===> Epoch[18](25/25): Loss: 0.0772 || Timer: 0.0031 sec.
# ===> Epoch 18 Complete: Avg. Loss: 0.0793
# ===> Epoch[19](1/25): Loss: 0.0818 || Timer: 0.0058 sec.
# ===> Epoch[19](2/25): Loss: 0.0774 || Timer: 0.0030 sec.
# ===> Epoch[19](3/25): Loss: 0.0777 || Timer: 0.0034 sec.
# ===> Epoch[19](4/25): Loss: 0.0953 || Timer: 0.0032 sec.
# ===> Epoch[19](5/25): Loss: 0.0842 || Timer: 0.0038 sec.
# ===> Epoch[19](6/25): Loss: 0.0865 || Timer: 0.0032 sec.
# ===> Epoch[19](7/25): Loss: 0.0847 || Timer: 0.0038 sec.
# ===> Epoch[19](8/25): Loss: 0.0684 || Timer: 0.0034 sec.
# ===> Epoch[19](9/25): Loss: 0.0936 || Timer: 0.0033 sec.
# ===> Epoch[19](10/25): Loss: 0.0859 || Timer: 0.0035 sec.
# ===> Epoch[19](11/25): Loss: 0.1007 || Timer: 0.0034 sec.
# ===> Epoch[19](12/25): Loss: 0.0921 || Timer: 0.0032 sec.
# ===> Epoch[19](13/25): Loss: 0.0849 || Timer: 0.0036 sec.
# ===> Epoch[19](14/25): Loss: 0.0899 || Timer: 0.0037 sec.
# ===> Epoch[19](15/25): Loss: 0.0801 || Timer: 0.0038 sec.
# ===> Epoch[19](16/25): Loss: 0.0800 || Timer: 0.0035 sec.
# ===> Epoch[19](17/25): Loss: 0.0710 || Timer: 0.0033 sec.
# ===> Epoch[19](18/25): Loss: 0.0868 || Timer: 0.0032 sec.
# ===> Epoch[19](19/25): Loss: 0.0770 || Timer: 0.0034 sec.
# ===> Epoch[19](20/25): Loss: 0.0762 || Timer: 0.0034 sec.
# ===> Epoch[19](21/25): Loss: 0.0808 || Timer: 0.0034 sec.
# ===> Epoch[19](22/25): Loss: 0.0566 || Timer: 0.0040 sec.
# ===> Epoch[19](23/25): Loss: 0.0874 || Timer: 0.0040 sec.
# ===> Epoch[19](24/25): Loss: 0.0886 || Timer: 0.0030 sec.
# ===> Epoch[19](25/25): Loss: 0.0659 || Timer: 0.0029 sec.
# ===> Epoch 19 Complete: Avg. Loss: 0.0821
# ===> Epoch[20](1/25): Loss: 0.0840 || Timer: 0.0054 sec.
# ===> Epoch[20](2/25): Loss: 0.0948 || Timer: 0.0042 sec.
# ===> Epoch[20](3/25): Loss: 0.0668 || Timer: 0.0035 sec.
# ===> Epoch[20](4/25): Loss: 0.0764 || Timer: 0.0029 sec.
# ===> Epoch[20](5/25): Loss: 0.0629 || Timer: 0.0039 sec.
# ===> Epoch[20](6/25): Loss: 0.0678 || Timer: 0.0040 sec.
# ===> Epoch[20](7/25): Loss: 0.0750 || Timer: 0.0036 sec.
# ===> Epoch[20](8/25): Loss: 0.0741 || Timer: 0.0029 sec.
# ===> Epoch[20](9/25): Loss: 0.0837 || Timer: 0.0030 sec.
# ===> Epoch[20](10/25): Loss: 0.0805 || Timer: 0.0034 sec.
# ===> Epoch[20](11/25): Loss: 0.0722 || Timer: 0.0032 sec.
# ===> Epoch[20](12/25): Loss: 0.0827 || Timer: 0.0053 sec.
# ===> Epoch[20](13/25): Loss: 0.0891 || Timer: 0.0035 sec.
# ===> Epoch[20](14/25): Loss: 0.0968 || Timer: 0.0041 sec.
# ===> Epoch[20](15/25): Loss: 0.0757 || Timer: 0.0041 sec.
# ===> Epoch[20](16/25): Loss: 0.0746 || Timer: 0.0041 sec.
# ===> Epoch[20](17/25): Loss: 0.0899 || Timer: 0.0040 sec.
# ===> Epoch[20](18/25): Loss: 0.1025 || Timer: 0.0034 sec.
# ===> Epoch[20](19/25): Loss: 0.0843 || Timer: 0.0036 sec.
# ===> Epoch[20](20/25): Loss: 0.0712 || Timer: 0.0042 sec.
# ===> Epoch[20](21/25): Loss: 0.0784 || Timer: 0.0031 sec.
# ===> Epoch[20](22/25): Loss: 0.0822 || Timer: 0.0035 sec.
# ===> Epoch[20](23/25): Loss: 0.0755 || Timer: 0.0035 sec.
# ===> Epoch[20](24/25): Loss: 0.0821 || Timer: 0.0038 sec.
# ===> Epoch[20](25/25): Loss: 0.0843 || Timer: 0.0031 sec.
# ===> Epoch 20 Complete: Avg. Loss: 0.0803
# Checkpoint saved to /content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_20.pth
# ===> Epoch[21](1/25): Loss: 0.0903 || Timer: 0.0049 sec.
# ===> Epoch[21](2/25): Loss: 0.0815 || Timer: 0.0042 sec.
# ===> Epoch[21](3/25): Loss: 0.0771 || Timer: 0.0040 sec.
# ===> Epoch[21](4/25): Loss: 0.0809 || Timer: 0.0033 sec.
# ===> Epoch[21](5/25): Loss: 0.0736 || Timer: 0.0033 sec.
# ===> Epoch[21](6/25): Loss: 0.1075 || Timer: 0.0035 sec.
# ===> Epoch[21](7/25): Loss: 0.0770 || Timer: 0.0037 sec.
# ===> Epoch[21](8/25): Loss: 0.0829 || Timer: 0.0036 sec.
# ===> Epoch[21](9/25): Loss: 0.0815 || Timer: 0.0036 sec.
# ===> Epoch[21](10/25): Loss: 0.0586 || Timer: 0.0033 sec.
# ===> Epoch[21](11/25): Loss: 0.0850 || Timer: 0.0040 sec.
# ===> Epoch[21](12/25): Loss: 0.0777 || Timer: 0.0032 sec.
# ===> Epoch[21](13/25): Loss: 0.0670 || Timer: 0.0031 sec.
# ===> Epoch[21](14/25): Loss: 0.0814 || Timer: 0.0041 sec.
# ===> Epoch[21](15/25): Loss: 0.0715 || Timer: 0.0043 sec.
# ===> Epoch[21](16/25): Loss: 0.0784 || Timer: 0.0036 sec.
# ===> Epoch[21](17/25): Loss: 0.0840 || Timer: 0.0033 sec.
# ===> Epoch[21](18/25): Loss: 0.0768 || Timer: 0.0037 sec.
# ===> Epoch[21](19/25): Loss: 0.0609 || Timer: 0.0038 sec.
# ===> Epoch[21](20/25): Loss: 0.0725 || Timer: 0.0031 sec.
# ===> Epoch[21](21/25): Loss: 0.0886 || Timer: 0.0042 sec.
# ===> Epoch[21](22/25): Loss: 0.0963 || Timer: 0.0036 sec.
# ===> Epoch[21](23/25): Loss: 0.0752 || Timer: 0.0035 sec.
# ===> Epoch[21](24/25): Loss: 0.0692 || Timer: 0.0030 sec.
# ===> Epoch[21](25/25): Loss: 0.0666 || Timer: 0.0031 sec.
# ===> Epoch 21 Complete: Avg. Loss: 0.0785
# ===> Epoch[22](1/25): Loss: 0.0832 || Timer: 0.0049 sec.
# ===> Epoch[22](2/25): Loss: 0.0887 || Timer: 0.0030 sec.
# ===> Epoch[22](3/25): Loss: 0.0553 || Timer: 0.0029 sec.
# ===> Epoch[22](4/25): Loss: 0.0819 || Timer: 0.0040 sec.
# ===> Epoch[22](5/25): Loss: 0.0782 || Timer: 0.0032 sec.
# ===> Epoch[22](6/25): Loss: 0.0684 || Timer: 0.0033 sec.
# ===> Epoch[22](7/25): Loss: 0.0699 || Timer: 0.0034 sec.
# ===> Epoch[22](8/25): Loss: 0.0907 || Timer: 0.0037 sec.
# ===> Epoch[22](9/25): Loss: 0.0778 || Timer: 0.0040 sec.
# ===> Epoch[22](10/25): Loss: 0.0827 || Timer: 0.0034 sec.
# ===> Epoch[22](11/25): Loss: 0.0838 || Timer: 0.0033 sec.
# ===> Epoch[22](12/25): Loss: 0.0840 || Timer: 0.0035 sec.
# ===> Epoch[22](13/25): Loss: 0.0926 || Timer: 0.0034 sec.
# ===> Epoch[22](14/25): Loss: 0.0708 || Timer: 0.0035 sec.
# ===> Epoch[22](15/25): Loss: 0.0770 || Timer: 0.0050 sec.
# ===> Epoch[22](16/25): Loss: 0.0731 || Timer: 0.0031 sec.
# ===> Epoch[22](17/25): Loss: 0.0995 || Timer: 0.0035 sec.
# ===> Epoch[22](18/25): Loss: 0.0771 || Timer: 0.0036 sec.
# ===> Epoch[22](19/25): Loss: 0.0784 || Timer: 0.0033 sec.
# ===> Epoch[22](20/25): Loss: 0.0681 || Timer: 0.0032 sec.
# ===> Epoch[22](21/25): Loss: 0.0880 || Timer: 0.0076 sec.
# ===> Epoch[22](22/25): Loss: 0.0712 || Timer: 0.0041 sec.
# ===> Epoch[22](23/25): Loss: 0.0660 || Timer: 0.0033 sec.
# ===> Epoch[22](24/25): Loss: 0.0730 || Timer: 0.0032 sec.
# ===> Epoch[22](25/25): Loss: 0.0589 || Timer: 0.0029 sec.
# ===> Epoch 22 Complete: Avg. Loss: 0.0775
# ===> Epoch[23](1/25): Loss: 0.0829 || Timer: 0.0052 sec.
# ===> Epoch[23](2/25): Loss: 0.0766 || Timer: 0.0039 sec.
# ===> Epoch[23](3/25): Loss: 0.0705 || Timer: 0.0036 sec.
# ===> Epoch[23](4/25): Loss: 0.0728 || Timer: 0.0036 sec.
# ===> Epoch[23](5/25): Loss: 0.0653 || Timer: 0.0033 sec.
# ===> Epoch[23](6/25): Loss: 0.0722 || Timer: 0.0041 sec.
# ===> Epoch[23](7/25): Loss: 0.0738 || Timer: 0.0037 sec.
# ===> Epoch[23](8/25): Loss: 0.1038 || Timer: 0.0040 sec.
# ===> Epoch[23](9/25): Loss: 0.0799 || Timer: 0.0033 sec.
# ===> Epoch[23](10/25): Loss: 0.0731 || Timer: 0.0034 sec.
# ===> Epoch[23](11/25): Loss: 0.0859 || Timer: 0.0038 sec.
# ===> Epoch[23](12/25): Loss: 0.0754 || Timer: 0.0034 sec.
# ===> Epoch[23](13/25): Loss: 0.0826 || Timer: 0.0042 sec.
# ===> Epoch[23](14/25): Loss: 0.0662 || Timer: 0.0036 sec.
# ===> Epoch[23](15/25): Loss: 0.0914 || Timer: 0.0030 sec.
# ===> Epoch[23](16/25): Loss: 0.0837 || Timer: 0.0033 sec.
# ===> Epoch[23](17/25): Loss: 0.0881 || Timer: 0.0032 sec.
# ===> Epoch[23](18/25): Loss: 0.0878 || Timer: 0.0034 sec.
# ===> Epoch[23](19/25): Loss: 0.0732 || Timer: 0.0030 sec.
# ===> Epoch[23](20/25): Loss: 0.0853 || Timer: 0.0041 sec.
# ===> Epoch[23](21/25): Loss: 0.0828 || Timer: 0.0040 sec.
# ===> Epoch[23](22/25): Loss: 0.0803 || Timer: 0.0035 sec.
# ===> Epoch[23](23/25): Loss: 0.0703 || Timer: 0.0032 sec.
# ===> Epoch[23](24/25): Loss: 0.0839 || Timer: 0.0041 sec.
# ===> Epoch[23](25/25): Loss: 0.0793 || Timer: 0.0029 sec.
# ===> Epoch 23 Complete: Avg. Loss: 0.0795
# ===> Epoch[24](1/25): Loss: 0.0592 || Timer: 0.0051 sec.
# ===> Epoch[24](2/25): Loss: 0.0777 || Timer: 0.0033 sec.
# ===> Epoch[24](3/25): Loss: 0.0908 || Timer: 0.0035 sec.
# ===> Epoch[24](4/25): Loss: 0.0877 || Timer: 0.0038 sec.
# ===> Epoch[24](5/25): Loss: 0.0943 || Timer: 0.0032 sec.
# ===> Epoch[24](6/25): Loss: 0.0843 || Timer: 0.0031 sec.
# ===> Epoch[24](7/25): Loss: 0.0928 || Timer: 0.0030 sec.
# ===> Epoch[24](8/25): Loss: 0.0876 || Timer: 0.0036 sec.
# ===> Epoch[24](9/25): Loss: 0.0720 || Timer: 0.0030 sec.
# ===> Epoch[24](10/25): Loss: 0.0921 || Timer: 0.0029 sec.
# ===> Epoch[24](11/25): Loss: 0.0833 || Timer: 0.0030 sec.
# ===> Epoch[24](12/25): Loss: 0.0849 || Timer: 0.0032 sec.
# ===> Epoch[24](13/25): Loss: 0.0896 || Timer: 0.0041 sec.
# ===> Epoch[24](14/25): Loss: 0.0939 || Timer: 0.0030 sec.
# ===> Epoch[24](15/25): Loss: 0.0737 || Timer: 0.0039 sec.
# ===> Epoch[24](16/25): Loss: 0.0775 || Timer: 0.0039 sec.
# ===> Epoch[24](17/25): Loss: 0.0555 || Timer: 0.0031 sec.
# ===> Epoch[24](18/25): Loss: 0.0852 || Timer: 0.0031 sec.
# ===> Epoch[24](19/25): Loss: 0.0706 || Timer: 0.0029 sec.
# ===> Epoch[24](20/25): Loss: 0.0818 || Timer: 0.0041 sec.
# ===> Epoch[24](21/25): Loss: 0.0743 || Timer: 0.0032 sec.
# ===> Epoch[24](22/25): Loss: 0.0798 || Timer: 0.0029 sec.
# ===> Epoch[24](23/25): Loss: 0.0911 || Timer: 0.0031 sec.
# ===> Epoch[24](24/25): Loss: 0.0784 || Timer: 0.0031 sec.
# ===> Epoch[24](25/25): Loss: 0.0736 || Timer: 0.0031 sec.
# ===> Epoch 24 Complete: Avg. Loss: 0.0813
# ===> Epoch[25](1/25): Loss: 0.0852 || Timer: 0.0063 sec.
# ===> Epoch[25](2/25): Loss: 0.0966 || Timer: 0.0041 sec.
# ===> Epoch[25](3/25): Loss: 0.0877 || Timer: 0.0039 sec.
# ===> Epoch[25](4/25): Loss: 0.0793 || Timer: 0.0037 sec.
# ===> Epoch[25](5/25): Loss: 0.1003 || Timer: 0.0043 sec.
# ===> Epoch[25](6/25): Loss: 0.0926 || Timer: 0.0039 sec.
# ===> Epoch[25](7/25): Loss: 0.0766 || Timer: 0.0033 sec.
# ===> Epoch[25](8/25): Loss: 0.0830 || Timer: 0.0037 sec.
# ===> Epoch[25](9/25): Loss: 0.0715 || Timer: 0.0033 sec.
# ===> Epoch[25](10/25): Loss: 0.0571 || Timer: 0.0034 sec.
# ===> Epoch[25](11/25): Loss: 0.0679 || Timer: 0.0031 sec.
# ===> Epoch[25](12/25): Loss: 0.0708 || Timer: 0.0040 sec.
# ===> Epoch[25](13/25): Loss: 0.0739 || Timer: 0.0037 sec.
# ===> Epoch[25](14/25): Loss: 0.0629 || Timer: 0.0040 sec.
# ===> Epoch[25](15/25): Loss: 0.0709 || Timer: 0.0033 sec.
# ===> Epoch[25](16/25): Loss: 0.0820 || Timer: 0.0033 sec.
# ===> Epoch[25](17/25): Loss: 0.0621 || Timer: 0.0034 sec.
# ===> Epoch[25](18/25): Loss: 0.0864 || Timer: 0.0031 sec.
# ===> Epoch[25](19/25): Loss: 0.0756 || Timer: 0.0031 sec.
# ===> Epoch[25](20/25): Loss: 0.0722 || Timer: 0.0034 sec.
# ===> Epoch[25](21/25): Loss: 0.0597 || Timer: 0.0033 sec.
# ===> Epoch[25](22/25): Loss: 0.0912 || Timer: 0.0040 sec.
# ===> Epoch[25](23/25): Loss: 0.0620 || Timer: 0.0033 sec.
# ===> Epoch[25](24/25): Loss: 0.0875 || Timer: 0.0038 sec.
# ===> Epoch[25](25/25): Loss: 0.0836 || Timer: 0.0029 sec.
# ===> Epoch 25 Complete: Avg. Loss: 0.0775
# ===> Epoch[26](1/25): Loss: 0.0997 || Timer: 0.0050 sec.
# ===> Epoch[26](2/25): Loss: 0.0845 || Timer: 0.0031 sec.
# ===> Epoch[26](3/25): Loss: 0.0766 || Timer: 0.0033 sec.
# ===> Epoch[26](4/25): Loss: 0.0792 || Timer: 0.0031 sec.
# ===> Epoch[26](5/25): Loss: 0.0817 || Timer: 0.0032 sec.
# ===> Epoch[26](6/25): Loss: 0.0862 || Timer: 0.0030 sec.
# ===> Epoch[26](7/25): Loss: 0.0733 || Timer: 0.0032 sec.
# ===> Epoch[26](8/25): Loss: 0.0795 || Timer: 0.0032 sec.
# ===> Epoch[26](9/25): Loss: 0.0904 || Timer: 0.0036 sec.
# ===> Epoch[26](10/25): Loss: 0.0788 || Timer: 0.0034 sec.
# ===> Epoch[26](11/25): Loss: 0.0913 || Timer: 0.0032 sec.
# ===> Epoch[26](12/25): Loss: 0.0724 || Timer: 0.0042 sec.
# ===> Epoch[26](13/25): Loss: 0.0659 || Timer: 0.0031 sec.
# ===> Epoch[26](14/25): Loss: 0.0801 || Timer: 0.0030 sec.
# ===> Epoch[26](15/25): Loss: 0.0657 || Timer: 0.0039 sec.
# ===> Epoch[26](16/25): Loss: 0.0795 || Timer: 0.0033 sec.
# ===> Epoch[26](17/25): Loss: 0.0797 || Timer: 0.0034 sec.
# ===> Epoch[26](18/25): Loss: 0.0693 || Timer: 0.0046 sec.
# ===> Epoch[26](19/25): Loss: 0.0840 || Timer: 0.0036 sec.
# ===> Epoch[26](20/25): Loss: 0.0821 || Timer: 0.0035 sec.
# ===> Epoch[26](21/25): Loss: 0.0890 || Timer: 0.0044 sec.
# ===> Epoch[26](22/25): Loss: 0.0896 || Timer: 0.0038 sec.
# ===> Epoch[26](23/25): Loss: 0.0772 || Timer: 0.0034 sec.
# ===> Epoch[26](24/25): Loss: 0.0716 || Timer: 0.0035 sec.
# ===> Epoch[26](25/25): Loss: 0.0863 || Timer: 0.0030 sec.
# ===> Epoch 26 Complete: Avg. Loss: 0.0805
# ===> Epoch[27](1/25): Loss: 0.0670 || Timer: 0.0064 sec.
# ===> Epoch[27](2/25): Loss: 0.0843 || Timer: 0.0036 sec.
# ===> Epoch[27](3/25): Loss: 0.0754 || Timer: 0.0036 sec.
# ===> Epoch[27](4/25): Loss: 0.0801 || Timer: 0.0032 sec.
# ===> Epoch[27](5/25): Loss: 0.0679 || Timer: 0.0039 sec.
# ===> Epoch[27](6/25): Loss: 0.0882 || Timer: 0.0035 sec.
# ===> Epoch[27](7/25): Loss: 0.0714 || Timer: 0.0033 sec.
# ===> Epoch[27](8/25): Loss: 0.0689 || Timer: 0.0035 sec.
# ===> Epoch[27](9/25): Loss: 0.0795 || Timer: 0.0031 sec.
# ===> Epoch[27](10/25): Loss: 0.0846 || Timer: 0.0036 sec.
# ===> Epoch[27](11/25): Loss: 0.0888 || Timer: 0.0040 sec.
# ===> Epoch[27](12/25): Loss: 0.0782 || Timer: 0.0030 sec.
# ===> Epoch[27](13/25): Loss: 0.0916 || Timer: 0.0035 sec.
# ===> Epoch[27](14/25): Loss: 0.0825 || Timer: 0.0042 sec.
# ===> Epoch[27](15/25): Loss: 0.0958 || Timer: 0.0033 sec.
# ===> Epoch[27](16/25): Loss: 0.0683 || Timer: 0.0031 sec.
# ===> Epoch[27](17/25): Loss: 0.0865 || Timer: 0.0037 sec.
# ===> Epoch[27](18/25): Loss: 0.0947 || Timer: 0.0038 sec.
# ===> Epoch[27](19/25): Loss: 0.0857 || Timer: 0.0041 sec.
# ===> Epoch[27](20/25): Loss: 0.0891 || Timer: 0.0038 sec.
# ===> Epoch[27](21/25): Loss: 0.0748 || Timer: 0.0033 sec.
# ===> Epoch[27](22/25): Loss: 0.0824 || Timer: 0.0033 sec.
# ===> Epoch[27](23/25): Loss: 0.0983 || Timer: 0.0033 sec.
# ===> Epoch[27](24/25): Loss: 0.0816 || Timer: 0.0039 sec.
# ===> Epoch[27](25/25): Loss: 0.0752 || Timer: 0.0032 sec.
# ===> Epoch 27 Complete: Avg. Loss: 0.0816
# ===> Epoch[28](1/25): Loss: 0.0959 || Timer: 0.0051 sec.
# ===> Epoch[28](2/25): Loss: 0.0661 || Timer: 0.0035 sec.
# ===> Epoch[28](3/25): Loss: 0.0722 || Timer: 0.0045 sec.
# ===> Epoch[28](4/25): Loss: 0.0593 || Timer: 0.0037 sec.
# ===> Epoch[28](5/25): Loss: 0.0937 || Timer: 0.0030 sec.
# ===> Epoch[28](6/25): Loss: 0.0772 || Timer: 0.0031 sec.
# ===> Epoch[28](7/25): Loss: 0.0888 || Timer: 0.0030 sec.
# ===> Epoch[28](8/25): Loss: 0.0762 || Timer: 0.0040 sec.
# ===> Epoch[28](9/25): Loss: 0.0791 || Timer: 0.0035 sec.
# ===> Epoch[28](10/25): Loss: 0.0854 || Timer: 0.0035 sec.
# ===> Epoch[28](11/25): Loss: 0.0706 || Timer: 0.0032 sec.
# ===> Epoch[28](12/25): Loss: 0.0901 || Timer: 0.0044 sec.
# ===> Epoch[28](13/25): Loss: 0.0740 || Timer: 0.0033 sec.
# ===> Epoch[28](14/25): Loss: 0.0837 || Timer: 0.0039 sec.
# ===> Epoch[28](15/25): Loss: 0.1002 || Timer: 0.0036 sec.
# ===> Epoch[28](16/25): Loss: 0.0702 || Timer: 0.0033 sec.
# ===> Epoch[28](17/25): Loss: 0.0776 || Timer: 0.0030 sec.
# ===> Epoch[28](18/25): Loss: 0.1104 || Timer: 0.0040 sec.
# ===> Epoch[28](19/25): Loss: 0.0781 || Timer: 0.0032 sec.
# ===> Epoch[28](20/25): Loss: 0.0785 || Timer: 0.0039 sec.
# ===> Epoch[28](21/25): Loss: 0.0776 || Timer: 0.0037 sec.
# ===> Epoch[28](22/25): Loss: 0.0734 || Timer: 0.0037 sec.
# ===> Epoch[28](23/25): Loss: 0.0879 || Timer: 0.0028 sec.
# ===> Epoch[28](24/25): Loss: 0.0846 || Timer: 0.0031 sec.
# ===> Epoch[28](25/25): Loss: 0.0868 || Timer: 0.0030 sec.
# ===> Epoch 28 Complete: Avg. Loss: 0.0815
# ===> Epoch[29](1/25): Loss: 0.0634 || Timer: 0.0054 sec.
# ===> Epoch[29](2/25): Loss: 0.0775 || Timer: 0.0043 sec.
# ===> Epoch[29](3/25): Loss: 0.0860 || Timer: 0.0035 sec.
# ===> Epoch[29](4/25): Loss: 0.0740 || Timer: 0.0038 sec.
# ===> Epoch[29](5/25): Loss: 0.0843 || Timer: 0.0041 sec.
# ===> Epoch[29](6/25): Loss: 0.0497 || Timer: 0.0028 sec.
# ===> Epoch[29](7/25): Loss: 0.0917 || Timer: 0.0034 sec.
# ===> Epoch[29](8/25): Loss: 0.0845 || Timer: 0.0032 sec.
# ===> Epoch[29](9/25): Loss: 0.0770 || Timer: 0.0029 sec.
# ===> Epoch[29](10/25): Loss: 0.0815 || Timer: 0.0038 sec.
# ===> Epoch[29](11/25): Loss: 0.1038 || Timer: 0.0039 sec.
# ===> Epoch[29](12/25): Loss: 0.0912 || Timer: 0.0034 sec.
# ===> Epoch[29](13/25): Loss: 0.0760 || Timer: 0.0038 sec.
# ===> Epoch[29](14/25): Loss: 0.0850 || Timer: 0.0040 sec.
# ===> Epoch[29](15/25): Loss: 0.0875 || Timer: 0.0031 sec.
# ===> Epoch[29](16/25): Loss: 0.0739 || Timer: 0.0040 sec.
# ===> Epoch[29](17/25): Loss: 0.0685 || Timer: 0.0035 sec.
# ===> Epoch[29](18/25): Loss: 0.0899 || Timer: 0.0033 sec.
# ===> Epoch[29](19/25): Loss: 0.1008 || Timer: 0.0035 sec.
# ===> Epoch[29](20/25): Loss: 0.0681 || Timer: 0.0039 sec.
# ===> Epoch[29](21/25): Loss: 0.0777 || Timer: 0.0035 sec.
# ===> Epoch[29](22/25): Loss: 0.0738 || Timer: 0.0038 sec.
# ===> Epoch[29](23/25): Loss: 0.0820 || Timer: 0.0033 sec.
# ===> Epoch[29](24/25): Loss: 0.0778 || Timer: 0.0039 sec.
# ===> Epoch[29](25/25): Loss: 0.1003 || Timer: 0.0028 sec.
# ===> Epoch 29 Complete: Avg. Loss: 0.0810
# ===> Epoch[30](1/25): Loss: 0.0696 || Timer: 0.0054 sec.
# ===> Epoch[30](2/25): Loss: 0.0698 || Timer: 0.0031 sec.
# ===> Epoch[30](3/25): Loss: 0.0787 || Timer: 0.0033 sec.
# ===> Epoch[30](4/25): Loss: 0.0763 || Timer: 0.0040 sec.
# ===> Epoch[30](5/25): Loss: 0.0857 || Timer: 0.0033 sec.
# ===> Epoch[30](6/25): Loss: 0.0610 || Timer: 0.0042 sec.
# ===> Epoch[30](7/25): Loss: 0.0729 || Timer: 0.0031 sec.
# ===> Epoch[30](8/25): Loss: 0.0924 || Timer: 0.0032 sec.
# ===> Epoch[30](9/25): Loss: 0.0675 || Timer: 0.0045 sec.
# ===> Epoch[30](10/25): Loss: 0.0816 || Timer: 0.0038 sec.
# ===> Epoch[30](11/25): Loss: 0.0792 || Timer: 0.0029 sec.
# ===> Epoch[30](12/25): Loss: 0.0875 || Timer: 0.0040 sec.
# ===> Epoch[30](13/25): Loss: 0.0853 || Timer: 0.0031 sec.
# ===> Epoch[30](14/25): Loss: 0.0729 || Timer: 0.0027 sec.
# ===> Epoch[30](15/25): Loss: 0.0813 || Timer: 0.0032 sec.
# ===> Epoch[30](16/25): Loss: 0.0873 || Timer: 0.0033 sec.
# ===> Epoch[30](17/25): Loss: 0.0991 || Timer: 0.0035 sec.
# ===> Epoch[30](18/25): Loss: 0.0816 || Timer: 0.0042 sec.
# ===> Epoch[30](19/25): Loss: 0.0823 || Timer: 0.0031 sec.
# ===> Epoch[30](20/25): Loss: 0.0899 || Timer: 0.0033 sec.
# ===> Epoch[30](21/25): Loss: 0.0787 || Timer: 0.0033 sec.
# ===> Epoch[30](22/25): Loss: 0.0834 || Timer: 0.0033 sec.
# ===> Epoch[30](23/25): Loss: 0.0799 || Timer: 0.0032 sec.
# ===> Epoch[30](24/25): Loss: 0.0708 || Timer: 0.0032 sec.
# ===> Epoch[30](25/25): Loss: 0.0907 || Timer: 0.0030 sec.
# ===> Epoch 30 Complete: Avg. Loss: 0.0802
# Checkpoint saved to /content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_30.pth
# ===> Epoch[31](1/25): Loss: 0.0828 || Timer: 0.0062 sec.
# ===> Epoch[31](2/25): Loss: 0.0839 || Timer: 0.0037 sec.
# ===> Epoch[31](3/25): Loss: 0.0826 || Timer: 0.0035 sec.
# ===> Epoch[31](4/25): Loss: 0.0843 || Timer: 0.0033 sec.
# ===> Epoch[31](5/25): Loss: 0.0897 || Timer: 0.0042 sec.
# ===> Epoch[31](6/25): Loss: 0.0651 || Timer: 0.0041 sec.
# ===> Epoch[31](7/25): Loss: 0.0709 || Timer: 0.0033 sec.
# ===> Epoch[31](8/25): Loss: 0.0839 || Timer: 0.0040 sec.
# ===> Epoch[31](9/25): Loss: 0.0728 || Timer: 0.0033 sec.
# ===> Epoch[31](10/25): Loss: 0.0665 || Timer: 0.0039 sec.
# ===> Epoch[31](11/25): Loss: 0.0804 || Timer: 0.0037 sec.
# ===> Epoch[31](12/25): Loss: 0.0920 || Timer: 0.0037 sec.
# ===> Epoch[31](13/25): Loss: 0.0795 || Timer: 0.0032 sec.
# ===> Epoch[31](14/25): Loss: 0.0842 || Timer: 0.0040 sec.
# ===> Epoch[31](15/25): Loss: 0.0900 || Timer: 0.0036 sec.
# ===> Epoch[31](16/25): Loss: 0.0766 || Timer: 0.0032 sec.
# ===> Epoch[31](17/25): Loss: 0.0880 || Timer: 0.0034 sec.
# ===> Epoch[31](18/25): Loss: 0.0731 || Timer: 0.0040 sec.
# ===> Epoch[31](19/25): Loss: 0.0862 || Timer: 0.0028 sec.
# ===> Epoch[31](20/25): Loss: 0.0704 || Timer: 0.0039 sec.
# ===> Epoch[31](21/25): Loss: 0.0896 || Timer: 0.0030 sec.
# ===> Epoch[31](22/25): Loss: 0.0737 || Timer: 0.0030 sec.
# ===> Epoch[31](23/25): Loss: 0.0692 || Timer: 0.0029 sec.
# ===> Epoch[31](24/25): Loss: 0.0860 || Timer: 0.0040 sec.
# ===> Epoch[31](25/25): Loss: 0.0798 || Timer: 0.0043 sec.
# ===> Epoch 31 Complete: Avg. Loss: 0.0800
# ===> Epoch[32](1/25): Loss: 0.0847 || Timer: 0.0052 sec.
# ===> Epoch[32](2/25): Loss: 0.0797 || Timer: 0.0033 sec.
# ===> Epoch[32](3/25): Loss: 0.0869 || Timer: 0.0037 sec.
# ===> Epoch[32](4/25): Loss: 0.0683 || Timer: 0.0039 sec.
# ===> Epoch[32](5/25): Loss: 0.0712 || Timer: 0.0033 sec.
# ===> Epoch[32](6/25): Loss: 0.0905 || Timer: 0.0032 sec.
# ===> Epoch[32](7/25): Loss: 0.0839 || Timer: 0.0031 sec.
# ===> Epoch[32](8/25): Loss: 0.0839 || Timer: 0.0039 sec.
# ===> Epoch[32](9/25): Loss: 0.0861 || Timer: 0.0041 sec.
# ===> Epoch[32](10/25): Loss: 0.0821 || Timer: 0.0030 sec.
# ===> Epoch[32](11/25): Loss: 0.0895 || Timer: 0.0038 sec.
# ===> Epoch[32](12/25): Loss: 0.0667 || Timer: 0.0033 sec.
# ===> Epoch[32](13/25): Loss: 0.0791 || Timer: 0.0031 sec.
# ...
# ===> Epoch[90](12/25): Loss: 0.0695 || Timer: 0.0040 sec.
# ===> Epoch[90](13/25): Loss: 0.0756 || Timer: 0.0037 sec.
# ===> Epoch[90](14/25): Loss: 0.0689 || Timer: 0.0038 sec.
# ===> Epoch[90](15/25): Loss: 0.1137 || Timer: 0.0034 sec.
# ===> Epoch[90](16/25): Loss: 0.0804 || Timer: 0.0038 sec.
# ===> Epoch[90](17/25): Loss: 0.0665 || Timer: 0.0035 sec.
# ===> Epoch[90](18/25): Loss: 0.0735 || Timer: 0.0033 sec.
# ===> Epoch[90](19/25): Loss: 0.0706 || Timer: 0.0033 sec.
# ===> Epoch[90](20/25): Loss: 0.0779 || Timer: 0.0032 sec.
# ===> Epoch[90](21/25): Loss: 0.0796 || Timer: 0.0041 sec.
# ===> Epoch[90](22/25): Loss: 0.0714 || Timer: 0.0036 sec.
# ===> Epoch[90](23/25): Loss: 0.0834 || Timer: 0.0038 sec.
# ===> Epoch[90](24/25): Loss: 0.0695 || Timer: 0.0030 sec.
# ===> Epoch[90](25/25): Loss: 0.0896 || Timer: 0.0028 sec.
# ===> Epoch 90 Complete: Avg. Loss: 0.0779
# Checkpoint saved to /content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_90.pth
# ===> Epoch[91](1/25): Loss: 0.0827 || Timer: 0.0064 sec.
# ===> Epoch[91](2/25): Loss: 0.0780 || Timer: 0.0037 sec.
# ===> Epoch[91](3/25): Loss: 0.0736 || Timer: 0.0042 sec.
# ===> Epoch[91](4/25): Loss: 0.0685 || Timer: 0.0032 sec.
# ===> Epoch[91](5/25): Loss: 0.0797 || Timer: 0.0033 sec.
# ===> Epoch[91](6/25): Loss: 0.0807 || Timer: 0.0033 sec.
# ===> Epoch[91](7/25): Loss: 0.0798 || Timer: 0.0043 sec.
# ===> Epoch[91](8/25): Loss: 0.0840 || Timer: 0.0040 sec.
# ===> Epoch[91](9/25): Loss: 0.0661 || Timer: 0.0039 sec.
# ===> Epoch[91](10/25): Loss: 0.0763 || Timer: 0.0039 sec.
# ===> Epoch[91](11/25): Loss: 0.0658 || Timer: 0.0033 sec.
# ===> Epoch[91](12/25): Loss: 0.0785 || Timer: 0.0039 sec.
# ===> Epoch[91](13/25): Loss: 0.0660 || Timer: 0.0032 sec.
# ===> Epoch[91](14/25): Loss: 0.0761 || Timer: 0.0041 sec.
# ===> Epoch[91](15/25): Loss: 0.0825 || Timer: 0.0035 sec.
# ===> Epoch[91](16/25): Loss: 0.0904 || Timer: 0.0036 sec.
# ===> Epoch[91](17/25): Loss: 0.0837 || Timer: 0.0041 sec.
# ===> Epoch[91](18/25): Loss: 0.0797 || Timer: 0.0041 sec.
# ===> Epoch[91](19/25): Loss: 0.0872 || Timer: 0.0033 sec.
# ===> Epoch[91](20/25): Loss: 0.0631 || Timer: 0.0040 sec.
# ===> Epoch[91](21/25): Loss: 0.0842 || Timer: 0.0032 sec.
# ===> Epoch[91](22/25): Loss: 0.0816 || Timer: 0.0040 sec.
# ===> Epoch[91](23/25): Loss: 0.0848 || Timer: 0.0033 sec.
# ===> Epoch[91](24/25): Loss: 0.0870 || Timer: 0.0038 sec.
# ===> Epoch[91](25/25): Loss: 0.0845 || Timer: 0.0029 sec.
# ===> Epoch 91 Complete: Avg. Loss: 0.0786
# ===> Epoch[92](1/25): Loss: 0.0772 || Timer: 0.0058 sec.
# ===> Epoch[92](2/25): Loss: 0.0728 || Timer: 0.0033 sec.
# ===> Epoch[92](3/25): Loss: 0.0827 || Timer: 0.0038 sec.
# ===> Epoch[92](4/25): Loss: 0.0711 || Timer: 0.0037 sec.
# ===> Epoch[92](5/25): Loss: 0.0702 || Timer: 0.0034 sec.
# ===> Epoch[92](6/25): Loss: 0.0774 || Timer: 0.0045 sec.
# ===> Epoch[92](7/25): Loss: 0.0983 || Timer: 0.0032 sec.
# ===> Epoch[92](8/25): Loss: 0.0851 || Timer: 0.0050 sec.
# ===> Epoch[92](9/25): Loss: 0.0792 || Timer: 0.0048 sec.
# ===> Epoch[92](10/25): Loss: 0.0752 || Timer: 0.0038 sec.
# ===> Epoch[92](11/25): Loss: 0.0873 || Timer: 0.0039 sec.
# ===> Epoch[92](12/25): Loss: 0.0669 || Timer: 0.0035 sec.
# ===> Epoch[92](13/25): Loss: 0.0723 || Timer: 0.0031 sec.
# ===> Epoch[92](14/25): Loss: 0.0751 || Timer: 0.0035 sec.
# ===> Epoch[92](15/25): Loss: 0.0742 || Timer: 0.0034 sec.
# ===> Epoch[92](16/25): Loss: 0.0693 || Timer: 0.0033 sec.
# ===> Epoch[92](17/25): Loss: 0.0759 || Timer: 0.0041 sec.
# ===> Epoch[92](18/25): Loss: 0.0747 || Timer: 0.0041 sec.
# ===> Epoch[92](19/25): Loss: 0.0771 || Timer: 0.0031 sec.
# ===> Epoch[92](20/25): Loss: 0.0925 || Timer: 0.0033 sec.
# ===> Epoch[92](21/25): Loss: 0.0705 || Timer: 0.0034 sec.
# ===> Epoch[92](22/25): Loss: 0.0719 || Timer: 0.0037 sec.
# ===> Epoch[92](23/25): Loss: 0.0831 || Timer: 0.0041 sec.
# ===> Epoch[92](24/25): Loss: 0.0776 || Timer: 0.0038 sec.
# ===> Epoch[92](25/25): Loss: 0.0898 || Timer: 0.0028 sec.
# ===> Epoch 92 Complete: Avg. Loss: 0.0779
# ===> Epoch[93](1/25): Loss: 0.0708 || Timer: 0.0054 sec.
# ===> Epoch[93](2/25): Loss: 0.0766 || Timer: 0.0042 sec.
# ===> Epoch[93](3/25): Loss: 0.0676 || Timer: 0.0031 sec.
# ===> Epoch[93](4/25): Loss: 0.0793 || Timer: 0.0040 sec.
# ===> Epoch[93](5/25): Loss: 0.0802 || Timer: 0.0040 sec.
# ===> Epoch[93](6/25): Loss: 0.0864 || Timer: 0.0032 sec.
# ===> Epoch[93](7/25): Loss: 0.0726 || Timer: 0.0037 sec.
# ===> Epoch[93](8/25): Loss: 0.0780 || Timer: 0.0030 sec.
# ===> Epoch[93](9/25): Loss: 0.0813 || Timer: 0.0032 sec.
# ===> Epoch[93](10/25): Loss: 0.0780 || Timer: 0.0034 sec.
# ===> Epoch[93](11/25): Loss: 0.0743 || Timer: 0.0039 sec.
# ===> Epoch[93](12/25): Loss: 0.0767 || Timer: 0.0034 sec.
# ===> Epoch[93](13/25): Loss: 0.0810 || Timer: 0.0032 sec.
# ===> Epoch[93](14/25): Loss: 0.0739 || Timer: 0.0041 sec.
# ===> Epoch[93](15/25): Loss: 0.0647 || Timer: 0.0038 sec.
# ===> Epoch[93](16/25): Loss: 0.0852 || Timer: 0.0039 sec.
# ===> Epoch[93](17/25): Loss: 0.0645 || Timer: 0.0034 sec.
# ===> Epoch[93](18/25): Loss: 0.0916 || Timer: 0.0040 sec.
# ===> Epoch[93](19/25): Loss: 0.0718 || Timer: 0.0033 sec.
# ===> Epoch[93](20/25): Loss: 0.0616 || Timer: 0.0031 sec.
# ===> Epoch[93](21/25): Loss: 0.0907 || Timer: 0.0033 sec.
# ===> Epoch[93](22/25): Loss: 0.0610 || Timer: 0.0034 sec.
# ===> Epoch[93](23/25): Loss: 0.0844 || Timer: 0.0032 sec.
# ===> Epoch[93](24/25): Loss: 0.0751 || Timer: 0.0030 sec.
# ===> Epoch[93](25/25): Loss: 0.0817 || Timer: 0.0030 sec.
# ===> Epoch 93 Complete: Avg. Loss: 0.0764
# ===> Epoch[94](1/25): Loss: 0.0780 || Timer: 0.0072 sec.
# ===> Epoch[94](2/25): Loss: 0.0754 || Timer: 0.0035 sec.
# ===> Epoch[94](3/25): Loss: 0.0952 || Timer: 0.0044 sec.
# ===> Epoch[94](4/25): Loss: 0.0933 || Timer: 0.0035 sec.
# ===> Epoch[94](5/25): Loss: 0.0791 || Timer: 0.0033 sec.
# ===> Epoch[94](6/25): Loss: 0.0777 || Timer: 0.0033 sec.
# ===> Epoch[94](7/25): Loss: 0.0686 || Timer: 0.0037 sec.
# ===> Epoch[94](8/25): Loss: 0.0840 || Timer: 0.0037 sec.
# ===> Epoch[94](9/25): Loss: 0.0666 || Timer: 0.0031 sec.
# ===> Epoch[94](10/25): Loss: 0.0648 || Timer: 0.0032 sec.
# ===> Epoch[94](11/25): Loss: 0.0744 || Timer: 0.0037 sec.
# ===> Epoch[94](12/25): Loss: 0.0648 || Timer: 0.0034 sec.
# ===> Epoch[94](13/25): Loss: 0.1026 || Timer: 0.0033 sec.
# ===> Epoch[94](14/25): Loss: 0.0834 || Timer: 0.0034 sec.
# ===> Epoch[94](15/25): Loss: 0.0947 || Timer: 0.0040 sec.
# ===> Epoch[94](16/25): Loss: 0.0674 || Timer: 0.0033 sec.
# ===> Epoch[94](17/25): Loss: 0.0913 || Timer: 0.0031 sec.
# ===> Epoch[94](18/25): Loss: 0.0726 || Timer: 0.0034 sec.
# ===> Epoch[94](19/25): Loss: 0.0898 || Timer: 0.0041 sec.
# ===> Epoch[94](20/25): Loss: 0.0664 || Timer: 0.0042 sec.
# ===> Epoch[94](21/25): Loss: 0.0583 || Timer: 0.0035 sec.
# ===> Epoch[94](22/25): Loss: 0.0694 || Timer: 0.0042 sec.
# ===> Epoch[94](23/25): Loss: 0.0665 || Timer: 0.0035 sec.
# ===> Epoch[94](24/25): Loss: 0.0780 || Timer: 0.0032 sec.
# ===> Epoch[94](25/25): Loss: 0.0951 || Timer: 0.0030 sec.
# ===> Epoch 94 Complete: Avg. Loss: 0.0783
# ===> Epoch[95](1/25): Loss: 0.0799 || Timer: 0.0062 sec.
# ===> Epoch[95](2/25): Loss: 0.0870 || Timer: 0.0041 sec.
# ===> Epoch[95](3/25): Loss: 0.0769 || Timer: 0.0032 sec.
# ===> Epoch[95](4/25): Loss: 0.0790 || Timer: 0.0043 sec.
# ===> Epoch[95](5/25): Loss: 0.0835 || Timer: 0.0042 sec.
# ===> Epoch[95](6/25): Loss: 0.0581 || Timer: 0.0035 sec.
# ===> Epoch[95](7/25): Loss: 0.0755 || Timer: 0.0039 sec.
# ===> Epoch[95](8/25): Loss: 0.0889 || Timer: 0.0033 sec.
# ===> Epoch[95](9/25): Loss: 0.0720 || Timer: 0.0031 sec.
# ===> Epoch[95](10/25): Loss: 0.0670 || Timer: 0.0040 sec.
# ===> Epoch[95](11/25): Loss: 0.0688 || Timer: 0.0029 sec.
# ===> Epoch[95](12/25): Loss: 0.0829 || Timer: 0.0030 sec.
# ===> Epoch[95](13/25): Loss: 0.0825 || Timer: 0.0028 sec.
# ===> Epoch[95](14/25): Loss: 0.0857 || Timer: 0.0040 sec.
# ===> Epoch[95](15/25): Loss: 0.0917 || Timer: 0.0035 sec.
# ===> Epoch[95](16/25): Loss: 0.0927 || Timer: 0.0031 sec.
# ===> Epoch[95](17/25): Loss: 0.0821 || Timer: 0.0038 sec.
# ===> Epoch[95](18/25): Loss: 0.0801 || Timer: 0.0031 sec.
# ===> Epoch[95](19/25): Loss: 0.0953 || Timer: 0.0035 sec.
# ===> Epoch[95](20/25): Loss: 0.0698 || Timer: 0.0033 sec.
# ===> Epoch[95](21/25): Loss: 0.0866 || Timer: 0.0039 sec.
# ===> Epoch[95](22/25): Loss: 0.0727 || Timer: 0.0040 sec.
# ===> Epoch[95](23/25): Loss: 0.0765 || Timer: 0.0040 sec.
# ===> Epoch[95](24/25): Loss: 0.0838 || Timer: 0.0034 sec.
# ===> Epoch[95](25/25): Loss: 0.0732 || Timer: 0.0030 sec.
# ===> Epoch 95 Complete: Avg. Loss: 0.0797
# ===> Epoch[96](1/25): Loss: 0.0882 || Timer: 0.0057 sec.
# ===> Epoch[96](2/25): Loss: 0.0708 || Timer: 0.0030 sec.
# ===> Epoch[96](3/25): Loss: 0.0767 || Timer: 0.0033 sec.
# ===> Epoch[96](4/25): Loss: 0.0799 || Timer: 0.0035 sec.
# ===> Epoch[96](5/25): Loss: 0.0719 || Timer: 0.0038 sec.
# ===> Epoch[96](6/25): Loss: 0.0653 || Timer: 0.0031 sec.
# ===> Epoch[96](7/25): Loss: 0.0851 || Timer: 0.0035 sec.
# ===> Epoch[96](8/25): Loss: 0.0894 || Timer: 0.0037 sec.
# ===> Epoch[96](9/25): Loss: 0.0707 || Timer: 0.0042 sec.
# ===> Epoch[96](10/25): Loss: 0.0882 || Timer: 0.0038 sec.
# ===> Epoch[96](11/25): Loss: 0.0767 || Timer: 0.0029 sec.
# ===> Epoch[96](12/25): Loss: 0.0910 || Timer: 0.0038 sec.
# ===> Epoch[96](13/25): Loss: 0.0891 || Timer: 0.0040 sec.
# ===> Epoch[96](14/25): Loss: 0.0832 || Timer: 0.0034 sec.
# ===> Epoch[96](15/25): Loss: 0.0663 || Timer: 0.0031 sec.
# ===> Epoch[96](16/25): Loss: 0.0666 || Timer: 0.0031 sec.
# ===> Epoch[96](17/25): Loss: 0.0756 || Timer: 0.0034 sec.
# ===> Epoch[96](18/25): Loss: 0.0724 || Timer: 0.0034 sec.
# ===> Epoch[96](19/25): Loss: 0.0751 || Timer: 0.0040 sec.
# ===> Epoch[96](20/25): Loss: 0.0739 || Timer: 0.0032 sec.
# ===> Epoch[96](21/25): Loss: 0.0841 || Timer: 0.0034 sec.
# ===> Epoch[96](22/25): Loss: 0.0624 || Timer: 0.0031 sec.
# ===> Epoch[96](23/25): Loss: 0.0843 || Timer: 0.0044 sec.
# ===> Epoch[96](24/25): Loss: 0.0813 || Timer: 0.0035 sec.
# ===> Epoch[96](25/25): Loss: 0.0948 || Timer: 0.0033 sec.
# ===> Epoch 96 Complete: Avg. Loss: 0.0785
# ===> Epoch[97](1/25): Loss: 0.0690 || Timer: 0.0065 sec.
# ===> Epoch[97](2/25): Loss: 0.0728 || Timer: 0.0035 sec.
# ===> Epoch[97](3/25): Loss: 0.0766 || Timer: 0.0042 sec.
# ===> Epoch[97](4/25): Loss: 0.0903 || Timer: 0.0041 sec.
# ===> Epoch[97](5/25): Loss: 0.0673 || Timer: 0.0034 sec.
# ===> Epoch[97](6/25): Loss: 0.0622 || Timer: 0.0039 sec.
# ===> Epoch[97](7/25): Loss: 0.0712 || Timer: 0.0030 sec.
# ===> Epoch[97](8/25): Loss: 0.0915 || Timer: 0.0036 sec.
# ===> Epoch[97](9/25): Loss: 0.0821 || Timer: 0.0030 sec.
# ===> Epoch[97](10/25): Loss: 0.0731 || Timer: 0.0035 sec.
# ===> Epoch[97](11/25): Loss: 0.0771 || Timer: 0.0039 sec.
# ===> Epoch[97](12/25): Loss: 0.0879 || Timer: 0.0038 sec.
# ===> Epoch[97](13/25): Loss: 0.0673 || Timer: 0.0035 sec.
# ===> Epoch[97](14/25): Loss: 0.0910 || Timer: 0.0037 sec.
# ===> Epoch[97](15/25): Loss: 0.0683 || Timer: 0.0037 sec.
# ===> Epoch[97](16/25): Loss: 0.0847 || Timer: 0.0030 sec.
# ===> Epoch[97](17/25): Loss: 0.0849 || Timer: 0.0033 sec.
# ===> Epoch[97](18/25): Loss: 0.0706 || Timer: 0.0031 sec.
# ===> Epoch[97](19/25): Loss: 0.0879 || Timer: 0.0030 sec.
# ===> Epoch[97](20/25): Loss: 0.0688 || Timer: 0.0031 sec.
# ===> Epoch[97](21/25): Loss: 0.0904 || Timer: 0.0034 sec.
# ===> Epoch[97](22/25): Loss: 0.0904 || Timer: 0.0038 sec.
# ===> Epoch[97](23/25): Loss: 0.0853 || Timer: 0.0029 sec.
# ===> Epoch[97](24/25): Loss: 0.0669 || Timer: 0.0031 sec.
# ===> Epoch[97](25/25): Loss: 0.0608 || Timer: 0.0030 sec.
# ===> Epoch 97 Complete: Avg. Loss: 0.0775
# ===> Epoch[98](1/25): Loss: 0.0802 || Timer: 0.0052 sec.
# ===> Epoch[98](2/25): Loss: 0.0700 || Timer: 0.0042 sec.
# ===> Epoch[98](3/25): Loss: 0.0696 || Timer: 0.0032 sec.
# ===> Epoch[98](4/25): Loss: 0.0779 || Timer: 0.0033 sec.
# ===> Epoch[98](5/25): Loss: 0.0761 || Timer: 0.0031 sec.
# ===> Epoch[98](6/25): Loss: 0.0663 || Timer: 0.0035 sec.
# ===> Epoch[98](7/25): Loss: 0.0728 || Timer: 0.0042 sec.
# ===> Epoch[98](8/25): Loss: 0.0827 || Timer: 0.0031 sec.
# ===> Epoch[98](9/25): Loss: 0.0784 || Timer: 0.0036 sec.
# ===> Epoch[98](10/25): Loss: 0.0778 || Timer: 0.0037 sec.
# ===> Epoch[98](11/25): Loss: 0.0676 || Timer: 0.0032 sec.
# ===> Epoch[98](12/25): Loss: 0.0817 || Timer: 0.0038 sec.
# ===> Epoch[98](13/25): Loss: 0.0731 || Timer: 0.0033 sec.
# ===> Epoch[98](14/25): Loss: 0.0954 || Timer: 0.0040 sec.
# ===> Epoch[98](15/25): Loss: 0.0750 || Timer: 0.0031 sec.
# ===> Epoch[98](16/25): Loss: 0.0663 || Timer: 0.0031 sec.
# ===> Epoch[98](17/25): Loss: 0.0574 || Timer: 0.0029 sec.
# ===> Epoch[98](18/25): Loss: 0.0732 || Timer: 0.0040 sec.
# ===> Epoch[98](19/25): Loss: 0.0593 || Timer: 0.0034 sec.
# ===> Epoch[98](20/25): Loss: 0.0882 || Timer: 0.0039 sec.
# ===> Epoch[98](21/25): Loss: 0.0922 || Timer: 0.0037 sec.
# ===> Epoch[98](22/25): Loss: 0.0673 || Timer: 0.0034 sec.
# ===> Epoch[98](23/25): Loss: 0.0876 || Timer: 0.0032 sec.
# ===> Epoch[98](24/25): Loss: 0.0770 || Timer: 0.0039 sec.
# ===> Epoch[98](25/25): Loss: 0.0730 || Timer: 0.0030 sec.
# ===> Epoch 98 Complete: Avg. Loss: 0.0754
# ===> Epoch[99](1/25): Loss: 0.0770 || Timer: 0.0057 sec.
# ===> Epoch[99](2/25): Loss: 0.0721 || Timer: 0.0035 sec.
# ===> Epoch[99](3/25): Loss: 0.0837 || Timer: 0.0033 sec.
# ===> Epoch[99](4/25): Loss: 0.0788 || Timer: 0.0041 sec.
# ===> Epoch[99](5/25): Loss: 0.0862 || Timer: 0.0033 sec.
# ===> Epoch[99](6/25): Loss: 0.0700 || Timer: 0.0033 sec.
# ===> Epoch[99](7/25): Loss: 0.0694 || Timer: 0.0033 sec.
# ===> Epoch[99](8/25): Loss: 0.0752 || Timer: 0.0042 sec.
# ===> Epoch[99](9/25): Loss: 0.0900 || Timer: 0.0036 sec.
# ===> Epoch[99](10/25): Loss: 0.0763 || Timer: 0.0040 sec.
# ===> Epoch[99](11/25): Loss: 0.0936 || Timer: 0.0042 sec.
# ===> Epoch[99](12/25): Loss: 0.1062 || Timer: 0.0035 sec.
# ===> Epoch[99](13/25): Loss: 0.0745 || Timer: 0.0031 sec.
# ===> Epoch[99](14/25): Loss: 0.0775 || Timer: 0.0031 sec.
# ===> Epoch[99](15/25): Loss: 0.0653 || Timer: 0.0032 sec.
# ===> Epoch[99](16/25): Loss: 0.0777 || Timer: 0.0041 sec.
# ===> Epoch[99](17/25): Loss: 0.0770 || Timer: 0.0041 sec.
# ===> Epoch[99](18/25): Loss: 0.0743 || Timer: 0.0031 sec.
# ===> Epoch[99](19/25): Loss: 0.0684 || Timer: 0.0033 sec.
# ===> Epoch[99](20/25): Loss: 0.0696 || Timer: 0.0037 sec.
# ===> Epoch[99](21/25): Loss: 0.0655 || Timer: 0.0030 sec.
# ===> Epoch[99](22/25): Loss: 0.0593 || Timer: 0.0036 sec.
# ===> Epoch[99](23/25): Loss: 0.0886 || Timer: 0.0033 sec.
# ===> Epoch[99](24/25): Loss: 0.0706 || Timer: 0.0035 sec.
# ===> Epoch[99](25/25): Loss: 0.0659 || Timer: 0.0028 sec.
# ===> Epoch 99 Complete: Avg. Loss: 0.0765
# ===> Epoch[100](1/25): Loss: 0.0733 || Timer: 0.0065 sec.
# ===> Epoch[100](2/25): Loss: 0.0919 || Timer: 0.0028 sec.
# ===> Epoch[100](3/25): Loss: 0.0654 || Timer: 0.0037 sec.
# ===> Epoch[100](4/25): Loss: 0.0721 || Timer: 0.0039 sec.
# ===> Epoch[100](5/25): Loss: 0.0667 || Timer: 0.0042 sec.
# ===> Epoch[100](6/25): Loss: 0.0787 || Timer: 0.0036 sec.
# ===> Epoch[100](7/25): Loss: 0.0773 || Timer: 0.0039 sec.
# ===> Epoch[100](8/25): Loss: 0.0712 || Timer: 0.0036 sec.
# ===> Epoch[100](9/25): Loss: 0.0604 || Timer: 0.0043 sec.
# ===> Epoch[100](10/25): Loss: 0.0786 || Timer: 0.0033 sec.
# ===> Epoch[100](11/25): Loss: 0.0770 || Timer: 0.0034 sec.
# ===> Epoch[100](12/25): Loss: 0.0772 || Timer: 0.0037 sec.
# ===> Epoch[100](13/25): Loss: 0.0881 || Timer: 0.0030 sec.
# ===> Epoch[100](14/25): Loss: 0.0803 || Timer: 0.0033 sec.
# ===> Epoch[100](15/25): Loss: 0.0736 || Timer: 0.0033 sec.
# ===> Epoch[100](16/25): Loss: 0.0656 || Timer: 0.0035 sec.
# ===> Epoch[100](17/25): Loss: 0.0634 || Timer: 0.0031 sec.
# ===> Epoch[100](18/25): Loss: 0.0745 || Timer: 0.0032 sec.
# ===> Epoch[100](19/25): Loss: 0.0717 || Timer: 0.0049 sec.
# ===> Epoch[100](20/25): Loss: 0.0764 || Timer: 0.0030 sec.
# ===> Epoch[100](21/25): Loss: 0.0835 || Timer: 0.0032 sec.
# ===> Epoch[100](22/25): Loss: 0.0760 || Timer: 0.0030 sec.
# ===> Epoch[100](23/25): Loss: 0.0661 || Timer: 0.0037 sec.
# ===> Epoch[100](24/25): Loss: 0.0879 || Timer: 0.0030 sec.
# ===> Epoch[100](25/25): Loss: 0.0762 || Timer: 0.0030 sec.
# ===> Epoch 100 Complete: Avg. Loss: 0.0749
# Checkpoint saved to /content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_100.pth
# Finished Training

# %%
# Test

from __future__ import print_function
import argparse

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from functools import reduce
from math import log10

# from scipy.misc import imsave
import scipy.io as sio
import time
import cv2
import easydict
from google.colab import drive
drive.mount('/content/gdrive')


opt = easydict.EasyDict({ 
    "testBatchSize": 1,     # 이미지를 1개씩불러옴 
    "upscale_factor": 2,    # Upscale 정도
    "input_channel": 3,     # WCNN model 입력의 Channel (color = 3, gray = 1)

    "model_type": "SRCNN",         # 모델이름
    
    "input_dir":"/content/gdrive/MyDrive/졸업논문/data_800개/test",  # test dataset 불러올위치
    "test_dataset": "low_color_test",                             # test에 사용할 dataset 종류
    "output": "/content/gdrive/MyDrive/졸업논문/졸업논문/Compare_Training/scale=2/results_scale=2/", # 결과영상 저장위치
    "model_type": "SRCNN",
    "model": "/content/gdrive/MyDrive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_100.pth",
    # test에 사용할 weight 불러올 파일 경로
    
    "pretrained": True,
    "data_augmentation": False,
    "gpu_mode": True,
    "threads": 0, 
    "gpus": 1 # 사용할 gpu 번호
    })

'''
1. GPU 설정 및 parameter print
'''
gpus_list = range(opt.gpus)
cudnn.benchmark = True
print(opt)

cuda = opt.gpu_mode
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

'''
2. Test Data 로드
'''
print('===> Loading datasets')
test_set = get_eval_set(os.path.join(opt.input_dir,opt.test_dataset), opt.upscale_factor)
testing_data_loader = DataLoader(dataset=test_set, num_workers=opt.threads, batch_size=opt.testBatchSize, shuffle=False)

'''
3. Criterion 정의 
  -> MSE loss 사용
'''
criterion = nn.MSELoss() 

'''
4. NN 정의
'''
model = SRCNN()

'''
5. pretrained model 및 GPU 사용 여부 설정
'''
if cuda:
    model = model.cuda(gpus_list[0])
    model = torch.nn.DataParallel(model, device_ids=gpus_list)
    criterion = criterion.cuda(gpus_list[0])
if opt.pretrained:
    model_name = os.path.join(opt.model)
    checkpoint = torch.load(model_name)

    model.load_state_dict(checkpoint['model_state_dict'])
    loss = checkpoint['loss']
    epoch = checkpoint['epoch']
    print('Pre-trained SR model is loaded.')
    # pretrained model 불러오기
    
'''
6. 이미지 저장 함수 -> 원본 이미지의 크기 그대로 저장 됨
'''
def save_img(img, img_name):
    save_img = img.squeeze().clamp(0, 1).numpy().transpose(1,2,0)
    # save img
    save_dir=os.path.join(opt.output,opt.test_dataset)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        
    save_fn = save_dir +'/'+ img_name
    cv2.imwrite(save_fn, cv2.cvtColor(save_img*255, cv2.COLOR_BGR2RGB),  [cv2.IMWRITE_PNG_COMPRESSION, 0])
    
'''
7. 한번의 epoch 에서 수행하는 과정 정의
'''
def eval():
    avg_psnr = 0
    psnr_sq = 0
    model.eval()
    count_image = 0
    # model.eval() 을 호출하여 평가(test) 모드로 변환 
    
    for batch_data in testing_data_loader:
        with torch.no_grad():
            input, bicubic, target, file_name = Variable(batch_data[0]), Variable(batch_data[1]), Variable(batch_data[2]), batch_data[3] 
                                                                
        if cuda:
            input = input.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])

        prediction = model(bicubic)
        print(prediction.shape, target.shape)

        if prediction.shape == target.shape:
          mse = criterion(prediction, target)
          psnr = 10 * log10(1 / mse.item())
          avg_psnr += psnr
          psnr_sq += psnr*psnr
          count_image += 1
        # Image.BICUBIC 에서 이미지의 H나 W가 3의 배수가 아니면 나머지를 버려버리기 때문에 prediction 과 target 의 shape 이 맞지 않는 경우가 생김
        

        save_img(prediction.cpu().data, 'SR_'+file_name[0])
        save_img(bicubic.cpu().data, 'blur_'+file_name[0])
        # save_img(target.cpu().data, file_name[0]+'/original')
       
    average = avg_psnr/count_image
    variance = psnr_sq/count_image-average*average
        
        # psnr 의 분산
    print('Image Amount: %d' %(count_image))
    print("===> epoch number : %d" % (epoch)) 
    print("===> Processing Done, Average PSNR : %.4f" % (average))
    print("===>PSNR Variance : %.4f" % (variance))
    
'''
우리는 훈련시에 128x128 이미지를 SR 하도록 훈련 했지만,
test 에서 입력 이미지의 크기는 상관이 없다
왜냐하면, 우리는 훈련하여 'filter' 를 얻었고,
입력의 크기가 128x128 가 아니더라도 훈련된 filter 를 stride 하면서 Conv. 연산 해 주면 되는 것이기 때문이다.
'''

##Eval Start!!!!
if __name__ == '__main__':
    eval()
    
print('finish')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# {'testBatchSize': 1, 'upscale_factor': 2, 'input_channel': 3, 'model_type': 'SRCNN', 'input_dir': '/content/gdrive/My Drive/졸업논문/data_800개/test', 'test_dataset': 'low_color_test', 'output': '/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/results_scale=2/', 'model': '/content/gdrive/My Drive/졸업논문/졸업논문/Compare_Training/scale=2/weights_scale=2/Compare_SRCNN_epoch_100.pth', 'pretrained': True, 'data_augmentation': False, 'gpu_mode': True, 'threads': 0, 'gpus': 1}
# ===> Loading datasets
# Pre-trained SR model is loaded.
# torch.Size([1, 3, 436, 700]) torch.Size([1, 3, 437, 700])
# torch.Size([1, 3, 534, 800]) torch.Size([1, 3, 534, 800])
# torch.Size([1, 3, 532, 800]) torch.Size([1, 3, 532, 800])
# Image Amount: 2
# ===> epoch number : 100
# ===> Processing Done, Average PSNR : 10.2135
# ===>PSNR Variance : 0.2819
# finish
